# %% [markdown]
# # Overview
#
# The aim of my project is to create a model which will predict wine rating based on its description written by a professsional wine-taster. I use the dataset "Wine reviews" from [Kaggle](https://www.kaggle.com/zynicide/wine-reviews). The dataset contains 130k observations scraped from [Wine Enthusiast](https://www.winemag.com/?s=&drink_type=win), a webpage selling wines and rating them. Each observation is a wine rated by Wine Enthusiast's experts. Apart from the rating and description, the dataset contains some other features e.g. country of origin of the wine, its designation, variety and price. In my project I concentrate on NLP analysis of the descriptions and building classification and regression models capable to predict wine rating based on the description.
#
# Dependent variable( feature "points") can be treated in three distinct ways:
#
# 1.   Divided into classes and treated as **nominal** classification target
# 2.   Divided into classes and treated as **ordinal ** classification target
# 3.   Left as it is and treated as a regression target.
#
# I will test and compare these three different approaches. For each approach I will built Neural Network (LSTM) and linear model (Logistic or Linear Regression). For nominal classification and regression I will also build XGBoost model. For each model I will do some hyperparameter tuning.

# %% [markdown]
# # Import of files and libraries

# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud, STOPWORDS
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from collections import Counter
import string
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.linear_model import LogisticRegression, LinearRegression
from xgboost.sklearn import XGBClassifier, XGBRegressor
from sklearn.metrics import accuracy_score, r2_score, mean_absolute_error, mean_squared_error
from sklearn.decomposition import LatentDirichletAllocation
import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()
from __future__ import print_function
import scipy.stats as ss
from sklearn.externals import joblib
import gensim
from gensim import corpora
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models.keyedvectors import KeyedVectors
from gensim.models import Word2Vec, word2vec
from gensim.utils import simple_preprocess
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.models import Sequential, load_model
from keras.layers.embeddings import Embedding
from keras.layers import Dense, Dropout, Embedding, SimpleRNN, LSTM, Bidirectional, MaxPooling1D, Conv1D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import np_utils, to_categorical 
from keras import regularizers
from keras import backend as K
import h5py
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import mord

# %%
data = pd.read_csv("data/winemag-data-130k-v2.csv", index_col=0)

# %%
data.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# In the future it will be exciting to compare predictive power of models based on NLP analysis of wines descriptions and the ones built with the rest of the features from the dataset. It's material for the next project.

# %% [markdown]
# # EDA

# %% [markdown]
# Dataset contains 129 971 wines descriptions written by 19 wine-tasters. First, let's make sure there are no duplicated records.

# %%
# checking for duplicates

for col in data.columns:
  print(f"{col}: {data[col].nunique()}")
print(f"\nNumber of observations: {len(data)}")
# Out:
# country: 43
# description: 119955
# designation: 37979
# points: 21
# price: 390
# province: 425
# region_1: 1229
# region_2: 17
# taster_name: 19
# taster_twitter_handle: 15
# title: 118840
# variety: 707
# winery: 16757
#
# Number of observations: 129971

# %% [markdown]
# There are ca. 10 000 wines with the same description in the dataset. It is quite odd as descriptions are detailed and seem to be tailor-made to suit specific wine. It could be the case of duplicated rows or that some wine tasters reuse templates for wine descriptions. The most important thing is to check if the same description corresponds to the same point score.

# %%
# checking if the wines with the same description have the same point score

duplicates = data[["description", "points"]][data.duplicated(subset="description", keep=False)]

counter = 0
for i in range(len(duplicates)):
  duplicated_indexes = np.where(duplicates["description"].iloc[i] == duplicates["description"])
  if duplicates["points"].iloc[duplicated_indexes[0][0]] == duplicates["points"].iloc[duplicated_indexes[0][1]]:
    counter +=1
    
print(counter/len(duplicates))
# Out:
# 0.9977029861180465

# %% [markdown]
# Conclusion: Almost all duplicated descriptions have the same score, so the rows are true duplicates and can be safely removed.

# %%
data = data.drop_duplicates(subset="description")

# %% [markdown]
# ### Country of wine origin

# %% [markdown]
# Reviewed wines come from 43 countries.

# %%
plt.figure(figsize=(14,6))
country = data.country.value_counts()[:10].sort_values(ascending=False)
country_plot = sns.countplot(x='country', data=data[data.country.isin(country.index.values)], order=country.index)
country_plot.set_title("Top 10 Countries Of Wine Origin", fontsize=25)
country_plot.set_xlabel("Countries", fontsize=15)
country_plot.set_ylabel("Count", fontsize=15)
country_plot.set_xticklabels(country.index,rotation=45)
plt.show()

# %% [markdown]
# ### Variety of wines

# %% [markdown]
# There are 707 differenet varieties of wines represented in the dataset.

# %%
plt.figure(figsize=(14,6))
variety = data.variety.value_counts()[:10]
variety_plot = sns.countplot(x='variety', data=data[data.variety.isin(variety.index.values)], order=variety.index)
variety_plot.set_title("Top 10 Varieties of Wine ", fontsize=25)
variety_plot.set_xlabel("Varieties", fontsize=15)
variety_plot.set_ylabel("Count", fontsize=15)
variety_plot.set_xticklabels(variety.index,rotation=45)
plt.show()

# %% [markdown]
# ### Points

# %%
plt.figure(figsize=(10,6))
points_plot = sns.countplot(x='points', data=data)
points_plot.set_title("Points distribution ", fontsize=25)
points_plot.set_xlabel("Points", fontsize=15)
points_plot.set_ylabel("Count", fontsize=15) 

print("Percentiles of points: ") 
print(data['points'].quantile([.01,.25,.5,.75,.99]))
# Out:
# Percentiles of points:
# 0.01    82.0
# 0.25    86.0
# 0.50    88.0
# 0.75    91.0
# 0.99    95.0
# Name: points, dtype: float64

# %% [markdown]
# 50% of wines scored between 86 and 91 points. Only 1% of wines got less than 82 points (scale beginning with 80) and 1% was above the 95 points threshold. The median is 88 points. Distribution of points is rather normal, a bit left-skewed with lower scores more prevalent than the highest.

# %% [markdown]
# ### Reviews (feature Description in the dataset)

# %%
desc_length = data['description'].apply(len)

print(f"The longest description contains: {desc_length.max()} characters")
print(f"The shortest description contains: {desc_length.min()} characters")
print(f"Median number of characters is: {desc_length.median()}")
print(f"Standard deviation of reviews: {np.std(desc_length)}")
# Out:
# The longest description contains: 829 characters
# The shortest description contains: 20 characters
# Median number of characters is: 237.0
# Standard deviation of reviews: 67.14651943090978

# %% [markdown]
# It's interesting that the length of review is positively correlated with the number of points.

# %%
data = data.assign(desc_length = data['description'].apply(len))

plt.figure(figsize=(14,6))
points_length = sns.boxplot(x='points', y='desc_length', data=data)
points_length.set_title('Points by review length', fontsize=25)
points_length.set_ylabel('Review length', fontsize = 15)
points_length.set_xlabel('Points', fontsize = 15) 
plt.show()

# %% [markdown]
# WordCloud of reviews shows most common words in reviews excluding stopwords.

# %%
stopwords = set(STOPWORDS)

newStopWords = ["Drink", "now", "offer", "offers", "flavor", "flavors"]

stopwords.update(newStopWords)

wordcloud = WordCloud(
    background_color='white',
    stopwords=stopwords,
    max_words=300,
    max_font_size=100, 
    width=1000, height=800,
    random_state=42,
).generate(" ".join(data['description']))

print(wordcloud)
fig = plt.figure(figsize = (12,14))
plt.imshow(wordcloud)
plt.title("WordCloud - wines reviews",fontsize=25)
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7fa6514398d0>

# %% [markdown]
# # Assigning variables

# %%
X = data["description"]
y = data["points"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, 
                                                          random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.15, 
                                                          random_state=52)

# %% [markdown]
# # Text preprocessing for LDA

# %% [markdown]
# First, in order to conduct topic analysis I have to preprocess reviews of wines:
#
# - make all words lowercase
# - remove stopwords
# - stem words
# - get rid of punctuation

# %%
def preprocess_descriptions(X):
  # 1.step: turning all words into lower case
  X_1 = X.str.lower()

  # 2.step: tokenizing descriptions (getting a list of all words used)
  X_2 = X.apply(nltk.word_tokenize)

  # 3.step: removing the stopwords
  stopwords = nltk.corpus.stopwords.words("english")
  X_3 = [[word for word in description if word not in stopwords] for description in X_2]

  # 4.step: stemming the words
  stemmer = nltk.PorterStemmer()
  X_4 = [[stemmer.stem(word) for word in description] for description in X_3]
  
  # 5.step: removing the stopwords again (some words were stemmed to a form of e.g "it", "the"
  # so they will be useless in analysis
  stopwords = nltk.corpus.stopwords.words("english")
  X_5 = [[word for word in description if word not in stopwords] for description in X_4]

  # 6.step: getting rid of punctuation  
  X_6 = [" ".join(word) for word in X_5]
  table = str.maketrans({key: None for key in string.punctuation})
  X_7 = [w.translate(table) for w in X_6]
  
  return X_7

# %%
X_train = preprocess_descriptions(X_train)
X_val = preprocess_descriptions(X_val)
X_test = preprocess_descriptions(X_test)

# %% [markdown]
# Reviews prepared in such a way are ready to be vectorized.
#
# I will use CountVectorizer with parameter max_df set to 0.5, which means that it will disregard words that are common to more than half of the reviews. Such words don't convey any unique meaning and don't have predictive power in case of my dataset. I will set min_df=2 as I don't want to take into account words that occured only once as it will lead to overfitting. However, I don't want to get rid of rare words altogether as some points were also very rare (e.g. 100 points) and these words may turn out specific to them.

# %%
#Creating vectorized reprezentation of descriptions

tf_vectorizer = CountVectorizer(max_df=0.5, min_df=2)
tf_vectorizer.fit(X_train)
X_train = tf_vectorizer.transform(X_train)
X_val = tf_vectorizer.transform(X_val)
X_test = tf_vectorizer.transform(X_test)

# %% [markdown]
# # Topic modelling (Latent Dirichlet Allocation)

# %% [markdown]
# My train data set has over 86 000 rows and over 15 000 columns. In order to reduce dimensionality and to extract topics I will use LDA.

# %%
# grid searching for best number of topics for LDA model

def find_best_lda_model(document_term_matrix, n_components):
  
  filename = "best_lda_model.joblib"
  
  lda = LatentDirichletAllocation(random_state=32)
  search_params = {'n_components': n_components}
  gs = GridSearchCV(lda, param_grid=search_params)
  gs.fit(document_term_matrix)
  
  joblib.dump(gs.best_estimator_, filename)
  
  print(gs.best_params_)
  
  return gs.best_estimator_

# %%
best_lda_model = find_best_lda_model(X_train, [3, 5, 7, 10]) # no need to run, best model saved and loaded below

# %%
best_lda_model = joblib.load("data/best_lda_model.joblib")

# %%
best_lda_model
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='batch', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=10, mean_change_tol=0.001,
#              n_components=5, n_jobs=None, n_topics=None, perp_tol=0.1,
#              random_state=32, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
# X_train, X_val, X_test will be now a matrix of LDA features

X_train_lda = best_lda_model.transform(X_train)
X_val_lda = best_lda_model.transform(X_val)
X_test_lda = best_lda_model.transform(X_test)

# %% [markdown]
# It turned out that the best number of topics is 5. Now I will visualize the topics with pyLDAvis.

# %%
LDA_vis = pyLDAvis.sklearn.prepare(best_lda_model, X_train, tf_vectorizer)

# %%
pyLDAvis.save_html(LDA_vis, "LDA_vis.html")

# %% [markdown]
# You can view the visualisation of the LDA topics [here](https://github.com/klauresh/DS_bootcamp_project/blob/master/LDA_vis.html).
#
# Interpretation:
# - Default circles represent LDA topics (area of the circles is proportionate to the proportion of all tokens comprised in the topic, e.g topic 1 which is most prevelant includes 24,6% of all tokens).
# - Blue bars represent frequency of the terms in the overall corpus (when no circle is selected) or in the specific topic (when a circle is selected).
# - Red bars represent the estimated number of times a given term was generated by a given topic.
# - Topic-term circles which appear after selecting a term are proportional to the frequencies with which a given term is estimated to have been generated by the topics.

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Nominal Classification

# %% [markdown]
# 1) classification model: y (points) binned into 3 classes and treated as nominal variable

# %%
#bin y into 3 classes of equal size
def bin_y(y):
  return pd.cut(y, [80, 86, 93, 100], labels = [0, 1, 2], right=True, include_lowest=True)

# %%
y_train = bin_y(y_train)
y_val = bin_y(y_val)
y_test = bin_y(y_test)

# %%
print(f"Number of observations in the classes:\n{bin_y(y).value_counts()}")
# Out:
# Number of observations in the classes:
# 1    81265
# 0    32674
# 2     6016
# Name: points, dtype: int64

# %% [markdown]
# I'm aware that the classes of y are imbalanced. However, I decided to go with it because another option, which was equal-frequency binning gave the following bins:

# %%
equal_frequency = pd.qcut(y, 3, labels = [0, 1, 2])
print(f"Points in the first bin: {np.sort(y[ef==0].unique())}")
print(f"Points in the second bin: {np.sort(y[ef==1].unique())}")
print(f"Points in the third bin: {np.sort(y[ef==2].unique())}")
# Out:
# Points in the first bin: [80 81 82 83 84 85 86 87]
# Points in the second bin: [88 89 90]
# Points in the third bin: [ 91  92  93  94  95  96  97  98  99 100]

# %% [markdown]
# I don't think it's practical to discern between such imbalanced sized bins as: 88-90 and 91-100 points wines.

# %% [markdown]
# ### Logistic Regression and XGBoost

# %% [markdown]
# First I will search for the best parameters for Logistic Regression and XGBoost, fit both models with best parameters and save them to a file.

# %%
best_logisticregression = "best_logisticregression.joblib" 
best_xgboost = "best_xgboost.joblib"


models = [LogisticRegression(), XGBClassifier(objective="multi:softmax", num_class=3)]

param_grids = [
    {"penalty": ["l1","l2"], 
     "C": ss.uniform(0.01,1)},
    
          {"n_estimators":ss.randint(10,300),
           "learning_rate":ss.uniform(0.01,0.3),
           "max_depth": ss.randint(5,30),
           "min_child_weight":ss.randint(5,50),
           "reg_lambda":ss.uniform(0.1,3)}
]


best_estimators =[]

for model, param_grid in zip(models, param_grids):
    
    cv = RandomizedSearchCV(cv=5, 
                        estimator=model,
                        param_distributions=param_grid,
                        n_iter=30,
                        verbose=2)
    cv.fit(X_train_lda, y_train)
    
    best_estimators.append(cv.best_estimator_)
    
    print(accuracy_score(cv.best_estimator_.predict(X_val_lda),y_val),
         cv.best_params_)
    

joblib.dump(best_estimators[0], best_logisticregression, compress=True)
joblib.dump(best_estimators[1], best_xgboost, compress=True)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] C=0.8193513856012646, penalty=l2 ................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................. C=0.8193513856012646, penalty=l2, total=   0.3s
# [CV] C=0.8193513856012646, penalty=l2 ................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV] ................. C=0.8193513856012646, penalty=l2, total=   0.3s
# [CV] C=0.8193513856012646, penalty=l2 ................................
# [CV] ................. C=0.8193513856012646, penalty=l2, total=   0.3s
# [CV] C=0.8193513856012646, penalty=l2 ................................
# [CV] ................. C=0.8193513856012646, penalty=l2, total=   0.3s
# [CV] C=0.8193513856012646, penalty=l2 ................................
# [CV] ................. C=0.8193513856012646, penalty=l2, total=   0.3s
# [CV] C=0.24455796122087337, penalty=l2 ...............................
# [CV] ................ C=0.24455796122087337, penalty=l2, total=   0.3s
# [CV] C=0.24455796122087337, penalty=l2 ...............................
# [CV] ................ C=0.24455796122087337, penalty=l2, total=   0.3s
# [CV] C=0.24455796122087337, penalty=l2 ...............................
# [CV] ................ C=0.24455796122087337, penalty=l2, total=   0.3s
# [CV] C=0.24455796122087337, penalty=l2 ...............................
# [CV] ................ C=0.24455796122087337, penalty=l2, total=   0.3s
# [CV] C=0.24455796122087337, penalty=l2 ...............................
# [CV] ................ C=0.24455796122087337, penalty=l2, total=   0.3s
# [CV] C=0.6549694374986018, penalty=l2 ................................
# [CV] ................. C=0.6549694374986018, penalty=l2, total=   0.3s
# [CV] C=0.6549694374986018, penalty=l2 ................................
# [CV] ................. C=0.6549694374986018, penalty=l2, total=   0.3s
# [CV] C=0.6549694374986018, penalty=l2 ................................
# [CV] ................. C=0.6549694374986018, penalty=l2, total=   0.3s
# [CV] C=0.6549694374986018, penalty=l2 ................................
# [CV] ................. C=0.6549694374986018, penalty=l2, total=   0.3s
# [CV] C=0.6549694374986018, penalty=l2 ................................
# [CV] ................. C=0.6549694374986018, penalty=l2, total=   0.3s
# [CV] C=0.9544422833529878, penalty=l1 ................................
# [CV] ................. C=0.9544422833529878, penalty=l1, total=   8.2s
# [CV] C=0.9544422833529878, penalty=l1 ................................
# [CV] ................. C=0.9544422833529878, penalty=l1, total=  11.5s
# [CV] C=0.9544422833529878, penalty=l1 ................................
# [CV] ................. C=0.9544422833529878, penalty=l1, total=  11.9s
# [CV] C=0.9544422833529878, penalty=l1 ................................
# [CV] ................. C=0.9544422833529878, penalty=l1, total=  11.5s
# [CV] C=0.9544422833529878, penalty=l1 ................................
# [CV] ................. C=0.9544422833529878, penalty=l1, total=   9.5s
# [CV] C=0.9226729570252395, penalty=l2 ................................
# [CV] ................. C=0.9226729570252395, penalty=l2, total=   0.3s
# [CV] C=0.9226729570252395, penalty=l2 ................................
# [CV] ................. C=0.9226729570252395, penalty=l2, total=   0.3s
# [CV] C=0.9226729570252395, penalty=l2 ................................
# [CV] ................. C=0.9226729570252395, penalty=l2, total=   0.3s
# [CV] C=0.9226729570252395, penalty=l2 ................................
# [CV] ................. C=0.9226729570252395, penalty=l2, total=   0.3s
# [CV] C=0.9226729570252395, penalty=l2 ................................
# [CV] ................. C=0.9226729570252395, penalty=l2, total=   0.3s
# [CV] C=0.6193738638520542, penalty=l1 ................................
# [CV] ................. C=0.6193738638520542, penalty=l1, total=   8.6s
# [CV] C=0.6193738638520542, penalty=l1 ................................
# [CV] ................. C=0.6193738638520542, penalty=l1, total=   5.5s
# [CV] C=0.6193738638520542, penalty=l1 ................................
# [CV] ................. C=0.6193738638520542, penalty=l1, total=   6.4s
# [CV] C=0.6193738638520542, penalty=l1 ................................
# [CV] ................. C=0.6193738638520542, penalty=l1, total=   6.6s
# [CV] C=0.6193738638520542, penalty=l1 ................................
# [CV] ................. C=0.6193738638520542, penalty=l1, total=   6.2s
# [CV] C=0.6411916589956195, penalty=l2 ................................
# [CV] ................. C=0.6411916589956195, penalty=l2, total=   0.3s
# [CV] C=0.6411916589956195, penalty=l2 ................................
# [CV] ................. C=0.6411916589956195, penalty=l2, total=   0.3s
# [CV] C=0.6411916589956195, penalty=l2 ................................
# [CV] ................. C=0.6411916589956195, penalty=l2, total=   0.3s
# [CV] C=0.6411916589956195, penalty=l2 ................................
# [CV] ................. C=0.6411916589956195, penalty=l2, total=   0.3s
# [CV] C=0.6411916589956195, penalty=l2 ................................
# [CV] ................. C=0.6411916589956195, penalty=l2, total=   0.3s
# [CV] C=0.3305297756659531, penalty=l1 ................................
# [CV] ................. C=0.3305297756659531, penalty=l1, total=   3.7s
# [CV] C=0.3305297756659531, penalty=l1 ................................
# [CV] ................. C=0.3305297756659531, penalty=l1, total=   2.0s
# [CV] C=0.3305297756659531, penalty=l1 ................................
# [CV] ................. C=0.3305297756659531, penalty=l1, total=   2.6s
# [CV] C=0.3305297756659531, penalty=l1 ................................
# [CV] ................. C=0.3305297756659531, penalty=l1, total=   3.5s
# [CV] C=0.3305297756659531, penalty=l1 ................................
# [CV] ................. C=0.3305297756659531, penalty=l1, total=   3.5s
# [CV] C=0.08319154712555075, penalty=l1 ...............................
# [CV] ................ C=0.08319154712555075, penalty=l1, total=   1.3s
# [CV] C=0.08319154712555075, penalty=l1 ...............................
# [CV] ................ C=0.08319154712555075, penalty=l1, total=   0.7s
# [CV] C=0.08319154712555075, penalty=l1 ...............................
# [CV] ................ C=0.08319154712555075, penalty=l1, total=   1.1s
# [CV] C=0.08319154712555075, penalty=l1 ...............................
# [CV] ................ C=0.08319154712555075, penalty=l1, total=   1.1s
# [CV] C=0.08319154712555075, penalty=l1 ...............................
# [CV] ................ C=0.08319154712555075, penalty=l1, total=   0.9s
# [CV] C=0.03295852058967518, penalty=l1 ...............................
# [CV] ................ C=0.03295852058967518, penalty=l1, total=   0.8s
# [CV] C=0.03295852058967518, penalty=l1 ...............................
# [CV] ................ C=0.03295852058967518, penalty=l1, total=   0.8s
# [CV] C=0.03295852058967518, penalty=l1 ...............................
# [CV] ................ C=0.03295852058967518, penalty=l1, total=   0.7s
# [CV] C=0.03295852058967518, penalty=l1 ...............................
# [CV] ................ C=0.03295852058967518, penalty=l1, total=   0.6s
# [CV] C=0.03295852058967518, penalty=l1 ...............................
# [CV] ................ C=0.03295852058967518, penalty=l1, total=   0.6s
# [CV] C=0.16671081317141645, penalty=l2 ...............................
# [CV] ................ C=0.16671081317141645, penalty=l2, total=   0.3s
# [CV] C=0.16671081317141645, penalty=l2 ...............................
# [CV] ................ C=0.16671081317141645, penalty=l2, total=   0.3s
# [CV] C=0.16671081317141645, penalty=l2 ...............................
# [CV] ................ C=0.16671081317141645, penalty=l2, total=   0.3s
# [CV] C=0.16671081317141645, penalty=l2 ...............................
# [CV] ................ C=0.16671081317141645, penalty=l2, total=   0.3s
# [CV] C=0.16671081317141645, penalty=l2 ...............................
# [CV] ................ C=0.16671081317141645, penalty=l2, total=   0.3s
# [CV] C=0.9418752706538922, penalty=l1 ................................
# [CV] ................. C=0.9418752706538922, penalty=l1, total=   5.6s
# [CV] C=0.9418752706538922, penalty=l1 ................................
# [CV] ................. C=0.9418752706538922, penalty=l1, total=   8.5s
# [CV] C=0.9418752706538922, penalty=l1 ................................
# [CV] ................. C=0.9418752706538922, penalty=l1, total=   8.0s
# [CV] C=0.9418752706538922, penalty=l1 ................................
# [CV] ................. C=0.9418752706538922, penalty=l1, total=   8.8s
# [CV] C=0.9418752706538922, penalty=l1 ................................
# [CV] ................. C=0.9418752706538922, penalty=l1, total=   7.8s
# [CV] C=0.5068914930624985, penalty=l1 ................................
# [CV] ................. C=0.5068914930624985, penalty=l1, total=   6.7s
# [CV] C=0.5068914930624985, penalty=l1 ................................
# [CV] ................. C=0.5068914930624985, penalty=l1, total=   4.9s
# [CV] C=0.5068914930624985, penalty=l1 ................................
# [CV] ................. C=0.5068914930624985, penalty=l1, total=   3.7s
# [CV] C=0.5068914930624985, penalty=l1 ................................
# [CV] ................. C=0.5068914930624985, penalty=l1, total=   6.1s
# [CV] C=0.5068914930624985, penalty=l1 ................................
# [CV] ................. C=0.5068914930624985, penalty=l1, total=   3.6s
# [CV] C=0.9670162446745453, penalty=l2 ................................
# [CV] ................. C=0.9670162446745453, penalty=l2, total=   0.3s
# [CV] C=0.9670162446745453, penalty=l2 ................................
# [CV] ................. C=0.9670162446745453, penalty=l2, total=   0.3s
# [CV] C=0.9670162446745453, penalty=l2 ................................
# [CV] ................. C=0.9670162446745453, penalty=l2, total=   0.3s
# [CV] C=0.9670162446745453, penalty=l2 ................................
# [CV] ................. C=0.9670162446745453, penalty=l2, total=   0.3s
# [CV] C=0.9670162446745453, penalty=l2 ................................
# [CV] ................. C=0.9670162446745453, penalty=l2, total=   0.3s
# [CV] C=0.4874613663022287, penalty=l1 ................................
# [CV] ................. C=0.4874613663022287, penalty=l1, total=   4.5s
# [CV] C=0.4874613663022287, penalty=l1 ................................
# [CV] ................. C=0.4874613663022287, penalty=l1, total=   3.7s
# [CV] C=0.4874613663022287, penalty=l1 ................................
# [CV] ................. C=0.4874613663022287, penalty=l1, total=   3.7s
# [CV] C=0.4874613663022287, penalty=l1 ................................
# [CV] ................. C=0.4874613663022287, penalty=l1, total=   5.9s
# [CV] C=0.4874613663022287, penalty=l1 ................................
# [CV] ................. C=0.4874613663022287, penalty=l1, total=   5.7s
# [CV] C=0.8849598310739313, penalty=l1 ................................
# [CV] ................. C=0.8849598310739313, penalty=l1, total=  11.7s
# [CV] C=0.8849598310739313, penalty=l1 ................................
# [CV] ................. C=0.8849598310739313, penalty=l1, total=   9.9s
# [CV] C=0.8849598310739313, penalty=l1 ................................
# [CV] ................. C=0.8849598310739313, penalty=l1, total=   6.4s
# [CV] C=0.8849598310739313, penalty=l1 ................................
# [CV] ................. C=0.8849598310739313, penalty=l1, total=   9.3s
# [CV] C=0.8849598310739313, penalty=l1 ................................
# [CV] ................. C=0.8849598310739313, penalty=l1, total=   5.4s
# [CV] C=0.21919228686217562, penalty=l1 ...............................
# [CV] ................ C=0.21919228686217562, penalty=l1, total=   2.6s
# [CV] C=0.21919228686217562, penalty=l1 ...............................
# [CV] ................ C=0.21919228686217562, penalty=l1, total=   2.0s
# [CV] C=0.21919228686217562, penalty=l1 ...............................
# [CV] ................ C=0.21919228686217562, penalty=l1, total=   2.5s
# [CV] C=0.21919228686217562, penalty=l1 ...............................
# [CV] ................ C=0.21919228686217562, penalty=l1, total=   2.6s
# [CV] C=0.21919228686217562, penalty=l1 ...............................
# [CV] ................ C=0.21919228686217562, penalty=l1, total=   2.4s
# [CV] C=0.3978971270965307, penalty=l2 ................................
# [CV] ................. C=0.3978971270965307, penalty=l2, total=   0.3s
# [CV] C=0.3978971270965307, penalty=l2 ................................
# [CV] ................. C=0.3978971270965307, penalty=l2, total=   0.3s
# [CV] C=0.3978971270965307, penalty=l2 ................................
# [CV] ................. C=0.3978971270965307, penalty=l2, total=   0.3s
# [CV] C=0.3978971270965307, penalty=l2 ................................
# [CV] ................. C=0.3978971270965307, penalty=l2, total=   0.3s
# [CV] C=0.3978971270965307, penalty=l2 ................................
# [CV] ................. C=0.3978971270965307, penalty=l2, total=   0.3s
# [CV] C=0.7598302318942478, penalty=l2 ................................
# [CV] ................. C=0.7598302318942478, penalty=l2, total=   0.3s
# [CV] C=0.7598302318942478, penalty=l2 ................................
# [CV] ................. C=0.7598302318942478, penalty=l2, total=   0.3s
# [CV] C=0.7598302318942478, penalty=l2 ................................
# [CV] ................. C=0.7598302318942478, penalty=l2, total=   0.3s
# [CV] C=0.7598302318942478, penalty=l2 ................................
# [CV] ................. C=0.7598302318942478, penalty=l2, total=   0.3s
# [CV] C=0.7598302318942478, penalty=l2 ................................
# [CV] ................. C=0.7598302318942478, penalty=l2, total=   0.3s
# [CV] C=0.4280283510655224, penalty=l1 ................................
# [CV] ................. C=0.4280283510655224, penalty=l1, total=   7.5s
# [CV] C=0.4280283510655224, penalty=l1 ................................
# [CV] ................. C=0.4280283510655224, penalty=l1, total=   5.2s
# [CV] C=0.4280283510655224, penalty=l1 ................................
# [CV] ................. C=0.4280283510655224, penalty=l1, total=   4.4s
# [CV] C=0.4280283510655224, penalty=l1 ................................
# [CV] ................. C=0.4280283510655224, penalty=l1, total=   4.7s
# [CV] C=0.4280283510655224, penalty=l1 ................................
# [CV] ................. C=0.4280283510655224, penalty=l1, total=   2.0s
# [CV] C=0.29887258432924035, penalty=l1 ...............................
# [CV] ................ C=0.29887258432924035, penalty=l1, total=   3.1s
# [CV] C=0.29887258432924035, penalty=l1 ...............................
# [CV] ................ C=0.29887258432924035, penalty=l1, total=   4.3s
# [CV] C=0.29887258432924035, penalty=l1 ...............................
# [CV] ................ C=0.29887258432924035, penalty=l1, total=   5.0s
# [CV] C=0.29887258432924035, penalty=l1 ...............................
# [CV] ................ C=0.29887258432924035, penalty=l1, total=   4.0s
# [CV] C=0.29887258432924035, penalty=l1 ...............................
# [CV] ................ C=0.29887258432924035, penalty=l1, total=   2.7s
# [CV] C=0.42813835414895907, penalty=l2 ...............................
# [CV] ................ C=0.42813835414895907, penalty=l2, total=   0.3s
# [CV] C=0.42813835414895907, penalty=l2 ...............................
# [CV] ................ C=0.42813835414895907, penalty=l2, total=   0.3s
# [CV] C=0.42813835414895907, penalty=l2 ...............................
# [CV] ................ C=0.42813835414895907, penalty=l2, total=   0.3s
# [CV] C=0.42813835414895907, penalty=l2 ...............................
# [CV] ................ C=0.42813835414895907, penalty=l2, total=   0.3s
# [CV] C=0.42813835414895907, penalty=l2 ...............................
# [CV] ................ C=0.42813835414895907, penalty=l2, total=   0.3s
# [CV] C=0.3477565451122182, penalty=l1 ................................
# [CV] ................. C=0.3477565451122182, penalty=l1, total=   4.1s
# [CV] C=0.3477565451122182, penalty=l1 ................................
# [CV] ................. C=0.3477565451122182, penalty=l1, total=   2.6s
# [CV] C=0.3477565451122182, penalty=l1 ................................
# [CV] ................. C=0.3477565451122182, penalty=l1, total=   3.9s
# [CV] C=0.3477565451122182, penalty=l1 ................................
# [CV] ................. C=0.3477565451122182, penalty=l1, total=   5.0s
# [CV] C=0.3477565451122182, penalty=l1 ................................
# [CV] ................. C=0.3477565451122182, penalty=l1, total=   2.2s
# [CV] C=0.8576159440858498, penalty=l1 ................................
# [CV] ................. C=0.8576159440858498, penalty=l1, total=   9.0s
# [CV] C=0.8576159440858498, penalty=l1 ................................
# [CV] ................. C=0.8576159440858498, penalty=l1, total=  10.7s
# [CV] C=0.8576159440858498, penalty=l1 ................................
# [CV] ................. C=0.8576159440858498, penalty=l1, total=   4.3s
# [CV] C=0.8576159440858498, penalty=l1 ................................
# [CV] ................. C=0.8576159440858498, penalty=l1, total=   9.2s
# [CV] C=0.8576159440858498, penalty=l1 ................................
# [CV] ................. C=0.8576159440858498, penalty=l1, total=   8.4s
# [CV] C=0.5239407863359249, penalty=l2 ................................
# [CV] ................. C=0.5239407863359249, penalty=l2, total=   0.3s
# [CV] C=0.5239407863359249, penalty=l2 ................................
# [CV] ................. C=0.5239407863359249, penalty=l2, total=   0.3s
# [CV] C=0.5239407863359249, penalty=l2 ................................
# [CV] ................. C=0.5239407863359249, penalty=l2, total=   0.3s
# [CV] C=0.5239407863359249, penalty=l2 ................................
# [CV] ................. C=0.5239407863359249, penalty=l2, total=   0.3s
# [CV] C=0.5239407863359249, penalty=l2 ................................
# [CV] ................. C=0.5239407863359249, penalty=l2, total=   0.3s
# [CV] C=0.42710549642993023, penalty=l2 ...............................
# [CV] ................ C=0.42710549642993023, penalty=l2, total=   0.3s
# [CV] C=0.42710549642993023, penalty=l2 ...............................
# [CV] ................ C=0.42710549642993023, penalty=l2, total=   0.3s
# [CV] C=0.42710549642993023, penalty=l2 ...............................
# [CV] ................ C=0.42710549642993023, penalty=l2, total=   0.3s
# [CV] C=0.42710549642993023, penalty=l2 ...............................
# [CV] ................ C=0.42710549642993023, penalty=l2, total=   0.3s
# [CV] C=0.42710549642993023, penalty=l2 ...............................
# [CV] ................ C=0.42710549642993023, penalty=l2, total=   0.3s
# [CV] C=0.25128070961959814, penalty=l2 ...............................
# [CV] ................ C=0.25128070961959814, penalty=l2, total=   0.3s
# [CV] C=0.25128070961959814, penalty=l2 ...............................
# [CV] ................ C=0.25128070961959814, penalty=l2, total=   0.3s
# [CV] C=0.25128070961959814, penalty=l2 ...............................
# [CV] ................ C=0.25128070961959814, penalty=l2, total=   0.3s
# [CV] C=0.25128070961959814, penalty=l2 ...............................
# [CV] ................ C=0.25128070961959814, penalty=l2, total=   0.3s
# [CV] C=0.25128070961959814, penalty=l2 ...............................
# [CV] ................ C=0.25128070961959814, penalty=l2, total=   0.3s
# [CV] C=0.4493765829332208, penalty=l2 ................................
# [CV] ................. C=0.4493765829332208, penalty=l2, total=   0.3s
# [CV] C=0.4493765829332208, penalty=l2 ................................
# [CV] ................. C=0.4493765829332208, penalty=l2, total=   0.3s
# [CV] C=0.4493765829332208, penalty=l2 ................................
# [CV] ................. C=0.4493765829332208, penalty=l2, total=   0.3s
# [CV] C=0.4493765829332208, penalty=l2 ................................
# [CV] ................. C=0.4493765829332208, penalty=l2, total=   0.3s
# [CV] C=0.4493765829332208, penalty=l2 ................................
# [CV] ................. C=0.4493765829332208, penalty=l2, total=   0.3s
# [CV] C=0.802385138304875, penalty=l2 .................................
# [CV] .................. C=0.802385138304875, penalty=l2, total=   0.3s
# [CV] C=0.802385138304875, penalty=l2 .................................
# [CV] .................. C=0.802385138304875, penalty=l2, total=   0.3s
# [CV] C=0.802385138304875, penalty=l2 .................................
# [CV] .................. C=0.802385138304875, penalty=l2, total=   0.3s
# [CV] C=0.802385138304875, penalty=l2 .................................
# [CV] .................. C=0.802385138304875, penalty=l2, total=   0.3s
# [CV] C=0.802385138304875, penalty=l2 .................................
# [CV] .................. C=0.802385138304875, penalty=l2, total=   0.3s
# [CV] C=0.7621729938174453, penalty=l1 ................................
# [CV] ................. C=0.7621729938174453, penalty=l1, total=  11.1s
# [CV] C=0.7621729938174453, penalty=l1 ................................
# [CV] ................. C=0.7621729938174453, penalty=l1, total=   5.2s
# [CV] C=0.7621729938174453, penalty=l1 ................................
# [CV] ................. C=0.7621729938174453, penalty=l1, total=   9.7s
# [CV] C=0.7621729938174453, penalty=l1 ................................
# [CV] ................. C=0.7621729938174453, penalty=l1, total=   9.5s
# [CV] C=0.7621729938174453, penalty=l1 ................................
# [CV] ................. C=0.7621729938174453, penalty=l1, total=   6.4s
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:  7.0min finished
# 0.6726381170317097 {'C': 0.8193513856012646, 'penalty': 'l2'}
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] learning_rate=0.12628571193865223, max_depth=15, min_child_weight=23, n_estimators=296, reg_lambda=1.6985719177915004
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  learning_rate=0.12628571193865223, max_depth=15, min_child_weight=23, n_estimators=296, reg_lambda=1.6985719177915004, total= 2.0min
# [CV] learning_rate=0.12628571193865223, max_depth=15, min_child_weight=23, n_estimators=296, reg_lambda=1.6985719177915004
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.2min remaining:    0.0s
# [CV]  learning_rate=0.12628571193865223, max_depth=15, min_child_weight=23, n_estimators=296, reg_lambda=1.6985719177915004, total= 2.0min
# [CV] learning_rate=0.12628571193865223, max_depth=15, min_child_weight=23, n_estimators=296, reg_lambda=1.6985719177915004
# [CV]  learning_rate=0.12628571193865223, max_depth=15, min_child_weight=23, n_estimators=296, reg_lambda=1.6985719177915004, total= 2.0min
# [CV] learning_rate=0.12628571193865223, max_depth=15, min_child_weight=23, n_estimators=296, reg_lambda=1.6985719177915004
# [CV]  learning_rate=0.12628571193865223, max_depth=15, min_child_weight=23, n_estimators=296, reg_lambda=1.6985719177915004, total= 2.0min
# [CV] learning_rate=0.12628571193865223, max_depth=15, min_child_weight=23, n_estimators=296, reg_lambda=1.6985719177915004
# [CV]  learning_rate=0.12628571193865223, max_depth=15, min_child_weight=23, n_estimators=296, reg_lambda=1.6985719177915004, total= 2.0min
# [CV] learning_rate=0.13785393122214654, max_depth=6, min_child_weight=45, n_estimators=102, reg_lambda=2.9891323333362916
# [CV]  learning_rate=0.13785393122214654, max_depth=6, min_child_weight=45, n_estimators=102, reg_lambda=2.9891323333362916, total=  19.6s
# [CV] learning_rate=0.13785393122214654, max_depth=6, min_child_weight=45, n_estimators=102, reg_lambda=2.9891323333362916
# [CV]  learning_rate=0.13785393122214654, max_depth=6, min_child_weight=45, n_estimators=102, reg_lambda=2.9891323333362916, total=  19.7s
# [CV] learning_rate=0.13785393122214654, max_depth=6, min_child_weight=45, n_estimators=102, reg_lambda=2.9891323333362916
# [CV]  learning_rate=0.13785393122214654, max_depth=6, min_child_weight=45, n_estimators=102, reg_lambda=2.9891323333362916, total=  19.4s
# [CV] learning_rate=0.13785393122214654, max_depth=6, min_child_weight=45, n_estimators=102, reg_lambda=2.9891323333362916
# [CV]  learning_rate=0.13785393122214654, max_depth=6, min_child_weight=45, n_estimators=102, reg_lambda=2.9891323333362916, total=  19.4s
# [CV] learning_rate=0.13785393122214654, max_depth=6, min_child_weight=45, n_estimators=102, reg_lambda=2.9891323333362916
# [CV]  learning_rate=0.13785393122214654, max_depth=6, min_child_weight=45, n_estimators=102, reg_lambda=2.9891323333362916, total=  19.4s
# [CV] learning_rate=0.1552397102924413, max_depth=10, min_child_weight=36, n_estimators=54, reg_lambda=1.356207488007154
# [CV]  learning_rate=0.1552397102924413, max_depth=10, min_child_weight=36, n_estimators=54, reg_lambda=1.356207488007154, total=  16.9s
# [CV] learning_rate=0.1552397102924413, max_depth=10, min_child_weight=36, n_estimators=54, reg_lambda=1.356207488007154
# [CV]  learning_rate=0.1552397102924413, max_depth=10, min_child_weight=36, n_estimators=54, reg_lambda=1.356207488007154, total=  17.1s
# [CV] learning_rate=0.1552397102924413, max_depth=10, min_child_weight=36, n_estimators=54, reg_lambda=1.356207488007154
# [CV]  learning_rate=0.1552397102924413, max_depth=10, min_child_weight=36, n_estimators=54, reg_lambda=1.356207488007154, total=  16.6s
# [CV] learning_rate=0.1552397102924413, max_depth=10, min_child_weight=36, n_estimators=54, reg_lambda=1.356207488007154
# [CV]  learning_rate=0.1552397102924413, max_depth=10, min_child_weight=36, n_estimators=54, reg_lambda=1.356207488007154, total=  16.4s
# [CV] learning_rate=0.1552397102924413, max_depth=10, min_child_weight=36, n_estimators=54, reg_lambda=1.356207488007154
# [CV]  learning_rate=0.1552397102924413, max_depth=10, min_child_weight=36, n_estimators=54, reg_lambda=1.356207488007154, total=  16.6s
# [CV] learning_rate=0.17321904484781245, max_depth=24, min_child_weight=18, n_estimators=21, reg_lambda=1.78468565805206
# [CV]  learning_rate=0.17321904484781245, max_depth=24, min_child_weight=18, n_estimators=21, reg_lambda=1.78468565805206, total=  12.8s
# [CV] learning_rate=0.17321904484781245, max_depth=24, min_child_weight=18, n_estimators=21, reg_lambda=1.78468565805206
# [CV]  learning_rate=0.17321904484781245, max_depth=24, min_child_weight=18, n_estimators=21, reg_lambda=1.78468565805206, total=  12.6s
# [CV] learning_rate=0.17321904484781245, max_depth=24, min_child_weight=18, n_estimators=21, reg_lambda=1.78468565805206
# [CV]  learning_rate=0.17321904484781245, max_depth=24, min_child_weight=18, n_estimators=21, reg_lambda=1.78468565805206, total=  12.9s
# [CV] learning_rate=0.17321904484781245, max_depth=24, min_child_weight=18, n_estimators=21, reg_lambda=1.78468565805206
# [CV]  learning_rate=0.17321904484781245, max_depth=24, min_child_weight=18, n_estimators=21, reg_lambda=1.78468565805206, total=  13.0s
# [CV] learning_rate=0.17321904484781245, max_depth=24, min_child_weight=18, n_estimators=21, reg_lambda=1.78468565805206
# [CV]  learning_rate=0.17321904484781245, max_depth=24, min_child_weight=18, n_estimators=21, reg_lambda=1.78468565805206, total=  12.6s
# [CV] learning_rate=0.2227990181679403, max_depth=19, min_child_weight=44, n_estimators=237, reg_lambda=0.5611311723394562
# [CV]  learning_rate=0.2227990181679403, max_depth=19, min_child_weight=44, n_estimators=237, reg_lambda=0.5611311723394562, total= 2.0min
# [CV] learning_rate=0.2227990181679403, max_depth=19, min_child_weight=44, n_estimators=237, reg_lambda=0.5611311723394562
# [CV]  learning_rate=0.2227990181679403, max_depth=19, min_child_weight=44, n_estimators=237, reg_lambda=0.5611311723394562, total= 1.9min
# [CV] learning_rate=0.2227990181679403, max_depth=19, min_child_weight=44, n_estimators=237, reg_lambda=0.5611311723394562
# [CV]  learning_rate=0.2227990181679403, max_depth=19, min_child_weight=44, n_estimators=237, reg_lambda=0.5611311723394562, total= 1.9min
# [CV] learning_rate=0.2227990181679403, max_depth=19, min_child_weight=44, n_estimators=237, reg_lambda=0.5611311723394562
# [CV]  learning_rate=0.2227990181679403, max_depth=19, min_child_weight=44, n_estimators=237, reg_lambda=0.5611311723394562, total= 1.9min
# [CV] learning_rate=0.2227990181679403, max_depth=19, min_child_weight=44, n_estimators=237, reg_lambda=0.5611311723394562
# [CV]  learning_rate=0.2227990181679403, max_depth=19, min_child_weight=44, n_estimators=237, reg_lambda=0.5611311723394562, total= 1.9min
# [CV] learning_rate=0.21160589413938166, max_depth=29, min_child_weight=45, n_estimators=253, reg_lambda=0.5277068326496009
# [CV]  learning_rate=0.21160589413938166, max_depth=29, min_child_weight=45, n_estimators=253, reg_lambda=0.5277068326496009, total= 3.0min
# [CV] learning_rate=0.21160589413938166, max_depth=29, min_child_weight=45, n_estimators=253, reg_lambda=0.5277068326496009
# [CV]  learning_rate=0.21160589413938166, max_depth=29, min_child_weight=45, n_estimators=253, reg_lambda=0.5277068326496009, total= 2.9min
# [CV] learning_rate=0.21160589413938166, max_depth=29, min_child_weight=45, n_estimators=253, reg_lambda=0.5277068326496009
# [CV]  learning_rate=0.21160589413938166, max_depth=29, min_child_weight=45, n_estimators=253, reg_lambda=0.5277068326496009, total= 2.9min
# [CV] learning_rate=0.21160589413938166, max_depth=29, min_child_weight=45, n_estimators=253, reg_lambda=0.5277068326496009
# [CV]  learning_rate=0.21160589413938166, max_depth=29, min_child_weight=45, n_estimators=253, reg_lambda=0.5277068326496009, total= 2.9min
# [CV] learning_rate=0.21160589413938166, max_depth=29, min_child_weight=45, n_estimators=253, reg_lambda=0.5277068326496009
# [CV]  learning_rate=0.21160589413938166, max_depth=29, min_child_weight=45, n_estimators=253, reg_lambda=0.5277068326496009, total= 3.0min
# [CV] learning_rate=0.028172289751846227, max_depth=29, min_child_weight=10, n_estimators=203, reg_lambda=1.7101896323753953
# [CV]  learning_rate=0.028172289751846227, max_depth=29, min_child_weight=10, n_estimators=203, reg_lambda=1.7101896323753953, total= 2.6min
# [CV] learning_rate=0.028172289751846227, max_depth=29, min_child_weight=10, n_estimators=203, reg_lambda=1.7101896323753953
# [CV]  learning_rate=0.028172289751846227, max_depth=29, min_child_weight=10, n_estimators=203, reg_lambda=1.7101896323753953, total= 2.5min
# [CV] learning_rate=0.028172289751846227, max_depth=29, min_child_weight=10, n_estimators=203, reg_lambda=1.7101896323753953
# [CV]  learning_rate=0.028172289751846227, max_depth=29, min_child_weight=10, n_estimators=203, reg_lambda=1.7101896323753953, total= 2.5min
# [CV] learning_rate=0.028172289751846227, max_depth=29, min_child_weight=10, n_estimators=203, reg_lambda=1.7101896323753953
# [CV]  learning_rate=0.028172289751846227, max_depth=29, min_child_weight=10, n_estimators=203, reg_lambda=1.7101896323753953, total= 2.5min
# [CV] learning_rate=0.028172289751846227, max_depth=29, min_child_weight=10, n_estimators=203, reg_lambda=1.7101896323753953
# [CV]  learning_rate=0.028172289751846227, max_depth=29, min_child_weight=10, n_estimators=203, reg_lambda=1.7101896323753953, total= 2.5min
# [CV] learning_rate=0.11084033680235655, max_depth=17, min_child_weight=33, n_estimators=63, reg_lambda=0.764896043698039
# [CV]  learning_rate=0.11084033680235655, max_depth=17, min_child_weight=33, n_estimators=63, reg_lambda=0.764896043698039, total=  29.6s
# [CV] learning_rate=0.11084033680235655, max_depth=17, min_child_weight=33, n_estimators=63, reg_lambda=0.764896043698039
# [CV]  learning_rate=0.11084033680235655, max_depth=17, min_child_weight=33, n_estimators=63, reg_lambda=0.764896043698039, total=  29.4s
# [CV] learning_rate=0.11084033680235655, max_depth=17, min_child_weight=33, n_estimators=63, reg_lambda=0.764896043698039
# [CV]  learning_rate=0.11084033680235655, max_depth=17, min_child_weight=33, n_estimators=63, reg_lambda=0.764896043698039, total=  28.0s
# [CV] learning_rate=0.11084033680235655, max_depth=17, min_child_weight=33, n_estimators=63, reg_lambda=0.764896043698039
# [CV]  learning_rate=0.11084033680235655, max_depth=17, min_child_weight=33, n_estimators=63, reg_lambda=0.764896043698039, total=  30.0s
# [CV] learning_rate=0.11084033680235655, max_depth=17, min_child_weight=33, n_estimators=63, reg_lambda=0.764896043698039
# [CV]  learning_rate=0.11084033680235655, max_depth=17, min_child_weight=33, n_estimators=63, reg_lambda=0.764896043698039, total=  30.1s
# [CV] learning_rate=0.28720241901932025, max_depth=29, min_child_weight=12, n_estimators=182, reg_lambda=0.6714793874831146
# [CV]  learning_rate=0.28720241901932025, max_depth=29, min_child_weight=12, n_estimators=182, reg_lambda=0.6714793874831146, total= 2.3min
# [CV] learning_rate=0.28720241901932025, max_depth=29, min_child_weight=12, n_estimators=182, reg_lambda=0.6714793874831146
# [CV]  learning_rate=0.28720241901932025, max_depth=29, min_child_weight=12, n_estimators=182, reg_lambda=0.6714793874831146, total= 2.3min
# [CV] learning_rate=0.28720241901932025, max_depth=29, min_child_weight=12, n_estimators=182, reg_lambda=0.6714793874831146
# [CV]  learning_rate=0.28720241901932025, max_depth=29, min_child_weight=12, n_estimators=182, reg_lambda=0.6714793874831146, total= 2.3min
# [CV] learning_rate=0.28720241901932025, max_depth=29, min_child_weight=12, n_estimators=182, reg_lambda=0.6714793874831146
# [CV]  learning_rate=0.28720241901932025, max_depth=29, min_child_weight=12, n_estimators=182, reg_lambda=0.6714793874831146, total= 2.3min
# [CV] learning_rate=0.28720241901932025, max_depth=29, min_child_weight=12, n_estimators=182, reg_lambda=0.6714793874831146
# [CV]  learning_rate=0.28720241901932025, max_depth=29, min_child_weight=12, n_estimators=182, reg_lambda=0.6714793874831146, total= 2.3min
# [CV] learning_rate=0.026943247829586903, max_depth=21, min_child_weight=14, n_estimators=176, reg_lambda=1.3435283893623398
# [CV]  learning_rate=0.026943247829586903, max_depth=21, min_child_weight=14, n_estimators=176, reg_lambda=1.3435283893623398, total= 1.8min
# [CV] learning_rate=0.026943247829586903, max_depth=21, min_child_weight=14, n_estimators=176, reg_lambda=1.3435283893623398
# [CV]  learning_rate=0.026943247829586903, max_depth=21, min_child_weight=14, n_estimators=176, reg_lambda=1.3435283893623398, total= 1.8min
# [CV] learning_rate=0.026943247829586903, max_depth=21, min_child_weight=14, n_estimators=176, reg_lambda=1.3435283893623398
# [CV]  learning_rate=0.026943247829586903, max_depth=21, min_child_weight=14, n_estimators=176, reg_lambda=1.3435283893623398, total= 1.8min
# [CV] learning_rate=0.026943247829586903, max_depth=21, min_child_weight=14, n_estimators=176, reg_lambda=1.3435283893623398
# [CV]  learning_rate=0.026943247829586903, max_depth=21, min_child_weight=14, n_estimators=176, reg_lambda=1.3435283893623398, total= 1.8min
# [CV] learning_rate=0.026943247829586903, max_depth=21, min_child_weight=14, n_estimators=176, reg_lambda=1.3435283893623398
# [CV]  learning_rate=0.026943247829586903, max_depth=21, min_child_weight=14, n_estimators=176, reg_lambda=1.3435283893623398, total= 1.8min
# [CV] learning_rate=0.19861454435361817, max_depth=23, min_child_weight=13, n_estimators=102, reg_lambda=2.6621176529655943
# [CV]  learning_rate=0.19861454435361817, max_depth=23, min_child_weight=13, n_estimators=102, reg_lambda=2.6621176529655943, total= 1.0min
# [CV] learning_rate=0.19861454435361817, max_depth=23, min_child_weight=13, n_estimators=102, reg_lambda=2.6621176529655943
# [CV]  learning_rate=0.19861454435361817, max_depth=23, min_child_weight=13, n_estimators=102, reg_lambda=2.6621176529655943, total= 1.1min
# [CV] learning_rate=0.19861454435361817, max_depth=23, min_child_weight=13, n_estimators=102, reg_lambda=2.6621176529655943
# [CV]  learning_rate=0.19861454435361817, max_depth=23, min_child_weight=13, n_estimators=102, reg_lambda=2.6621176529655943, total= 1.0min
# [CV] learning_rate=0.19861454435361817, max_depth=23, min_child_weight=13, n_estimators=102, reg_lambda=2.6621176529655943
# [CV]  learning_rate=0.19861454435361817, max_depth=23, min_child_weight=13, n_estimators=102, reg_lambda=2.6621176529655943, total= 1.1min
# [CV] learning_rate=0.19861454435361817, max_depth=23, min_child_weight=13, n_estimators=102, reg_lambda=2.6621176529655943
# [CV]  learning_rate=0.19861454435361817, max_depth=23, min_child_weight=13, n_estimators=102, reg_lambda=2.6621176529655943, total= 1.0min
# [CV] learning_rate=0.1302001867062858, max_depth=28, min_child_weight=9, n_estimators=76, reg_lambda=1.9790873714535964
# [CV]  learning_rate=0.1302001867062858, max_depth=28, min_child_weight=9, n_estimators=76, reg_lambda=1.9790873714535964, total=  55.3s
# [CV] learning_rate=0.1302001867062858, max_depth=28, min_child_weight=9, n_estimators=76, reg_lambda=1.9790873714535964
# [CV]  learning_rate=0.1302001867062858, max_depth=28, min_child_weight=9, n_estimators=76, reg_lambda=1.9790873714535964, total=  52.8s
# [CV] learning_rate=0.1302001867062858, max_depth=28, min_child_weight=9, n_estimators=76, reg_lambda=1.9790873714535964
# [CV]  learning_rate=0.1302001867062858, max_depth=28, min_child_weight=9, n_estimators=76, reg_lambda=1.9790873714535964, total=  55.6s
# [CV] learning_rate=0.1302001867062858, max_depth=28, min_child_weight=9, n_estimators=76, reg_lambda=1.9790873714535964
# [CV]  learning_rate=0.1302001867062858, max_depth=28, min_child_weight=9, n_estimators=76, reg_lambda=1.9790873714535964, total=  53.6s
# [CV] learning_rate=0.1302001867062858, max_depth=28, min_child_weight=9, n_estimators=76, reg_lambda=1.9790873714535964
# [CV]  learning_rate=0.1302001867062858, max_depth=28, min_child_weight=9, n_estimators=76, reg_lambda=1.9790873714535964, total=  53.8s
# [CV] learning_rate=0.28077966086752904, max_depth=9, min_child_weight=29, n_estimators=58, reg_lambda=1.3934885204234235
# [CV]  learning_rate=0.28077966086752904, max_depth=9, min_child_weight=29, n_estimators=58, reg_lambda=1.3934885204234235, total=  15.2s
# [CV] learning_rate=0.28077966086752904, max_depth=9, min_child_weight=29, n_estimators=58, reg_lambda=1.3934885204234235
# [CV]  learning_rate=0.28077966086752904, max_depth=9, min_child_weight=29, n_estimators=58, reg_lambda=1.3934885204234235, total=  15.4s
# [CV] learning_rate=0.28077966086752904, max_depth=9, min_child_weight=29, n_estimators=58, reg_lambda=1.3934885204234235
# [CV]  learning_rate=0.28077966086752904, max_depth=9, min_child_weight=29, n_estimators=58, reg_lambda=1.3934885204234235, total=  15.4s
# [CV] learning_rate=0.28077966086752904, max_depth=9, min_child_weight=29, n_estimators=58, reg_lambda=1.3934885204234235
# [CV]  learning_rate=0.28077966086752904, max_depth=9, min_child_weight=29, n_estimators=58, reg_lambda=1.3934885204234235, total=  15.3s
# [CV] learning_rate=0.28077966086752904, max_depth=9, min_child_weight=29, n_estimators=58, reg_lambda=1.3934885204234235
# [CV]  learning_rate=0.28077966086752904, max_depth=9, min_child_weight=29, n_estimators=58, reg_lambda=1.3934885204234235, total=  15.7s
# [CV] learning_rate=0.25735604513243726, max_depth=9, min_child_weight=27, n_estimators=63, reg_lambda=1.4132967192741004
# [CV]  learning_rate=0.25735604513243726, max_depth=9, min_child_weight=27, n_estimators=63, reg_lambda=1.4132967192741004, total=  16.8s
# [CV] learning_rate=0.25735604513243726, max_depth=9, min_child_weight=27, n_estimators=63, reg_lambda=1.4132967192741004
# [CV]  learning_rate=0.25735604513243726, max_depth=9, min_child_weight=27, n_estimators=63, reg_lambda=1.4132967192741004, total=  17.2s
# [CV] learning_rate=0.25735604513243726, max_depth=9, min_child_weight=27, n_estimators=63, reg_lambda=1.4132967192741004
# [CV]  learning_rate=0.25735604513243726, max_depth=9, min_child_weight=27, n_estimators=63, reg_lambda=1.4132967192741004, total=  17.2s
# [CV] learning_rate=0.25735604513243726, max_depth=9, min_child_weight=27, n_estimators=63, reg_lambda=1.4132967192741004
# [CV]  learning_rate=0.25735604513243726, max_depth=9, min_child_weight=27, n_estimators=63, reg_lambda=1.4132967192741004, total=  17.3s
# [CV] learning_rate=0.25735604513243726, max_depth=9, min_child_weight=27, n_estimators=63, reg_lambda=1.4132967192741004
# [CV]  learning_rate=0.25735604513243726, max_depth=9, min_child_weight=27, n_estimators=63, reg_lambda=1.4132967192741004, total=  16.8s
# [CV] learning_rate=0.19430585013627802, max_depth=25, min_child_weight=49, n_estimators=109, reg_lambda=3.056652855970654
# [CV]  learning_rate=0.19430585013627802, max_depth=25, min_child_weight=49, n_estimators=109, reg_lambda=3.056652855970654, total= 1.1min
# [CV] learning_rate=0.19430585013627802, max_depth=25, min_child_weight=49, n_estimators=109, reg_lambda=3.056652855970654
# [CV]  learning_rate=0.19430585013627802, max_depth=25, min_child_weight=49, n_estimators=109, reg_lambda=3.056652855970654, total= 1.1min
# [CV] learning_rate=0.19430585013627802, max_depth=25, min_child_weight=49, n_estimators=109, reg_lambda=3.056652855970654
# [CV]  learning_rate=0.19430585013627802, max_depth=25, min_child_weight=49, n_estimators=109, reg_lambda=3.056652855970654, total= 1.1min
# [CV] learning_rate=0.19430585013627802, max_depth=25, min_child_weight=49, n_estimators=109, reg_lambda=3.056652855970654
# [CV]  learning_rate=0.19430585013627802, max_depth=25, min_child_weight=49, n_estimators=109, reg_lambda=3.056652855970654, total= 1.1min
# [CV] learning_rate=0.19430585013627802, max_depth=25, min_child_weight=49, n_estimators=109, reg_lambda=3.056652855970654
# [CV]  learning_rate=0.19430585013627802, max_depth=25, min_child_weight=49, n_estimators=109, reg_lambda=3.056652855970654, total= 1.0min
# [CV] learning_rate=0.20344140804179767, max_depth=14, min_child_weight=9, n_estimators=98, reg_lambda=2.8387836900966072
# [CV]  learning_rate=0.20344140804179767, max_depth=14, min_child_weight=9, n_estimators=98, reg_lambda=2.8387836900966072, total=  39.9s
# [CV] learning_rate=0.20344140804179767, max_depth=14, min_child_weight=9, n_estimators=98, reg_lambda=2.8387836900966072
# [CV]  learning_rate=0.20344140804179767, max_depth=14, min_child_weight=9, n_estimators=98, reg_lambda=2.8387836900966072, total=  39.9s
# [CV] learning_rate=0.20344140804179767, max_depth=14, min_child_weight=9, n_estimators=98, reg_lambda=2.8387836900966072
# [CV]  learning_rate=0.20344140804179767, max_depth=14, min_child_weight=9, n_estimators=98, reg_lambda=2.8387836900966072, total=  38.8s
# [CV] learning_rate=0.20344140804179767, max_depth=14, min_child_weight=9, n_estimators=98, reg_lambda=2.8387836900966072
# [CV]  learning_rate=0.20344140804179767, max_depth=14, min_child_weight=9, n_estimators=98, reg_lambda=2.8387836900966072, total=  40.0s
# [CV] learning_rate=0.20344140804179767, max_depth=14, min_child_weight=9, n_estimators=98, reg_lambda=2.8387836900966072
# [CV]  learning_rate=0.20344140804179767, max_depth=14, min_child_weight=9, n_estimators=98, reg_lambda=2.8387836900966072, total=  40.2s
# [CV] learning_rate=0.03409976001133041, max_depth=21, min_child_weight=30, n_estimators=63, reg_lambda=1.8232796195840406
# [CV]  learning_rate=0.03409976001133041, max_depth=21, min_child_weight=30, n_estimators=63, reg_lambda=1.8232796195840406, total=  34.5s
# [CV] learning_rate=0.03409976001133041, max_depth=21, min_child_weight=30, n_estimators=63, reg_lambda=1.8232796195840406
# [CV]  learning_rate=0.03409976001133041, max_depth=21, min_child_weight=30, n_estimators=63, reg_lambda=1.8232796195840406, total=  33.9s
# [CV] learning_rate=0.03409976001133041, max_depth=21, min_child_weight=30, n_estimators=63, reg_lambda=1.8232796195840406
# [CV]  learning_rate=0.03409976001133041, max_depth=21, min_child_weight=30, n_estimators=63, reg_lambda=1.8232796195840406, total=  34.5s
# [CV] learning_rate=0.03409976001133041, max_depth=21, min_child_weight=30, n_estimators=63, reg_lambda=1.8232796195840406
# [CV]  learning_rate=0.03409976001133041, max_depth=21, min_child_weight=30, n_estimators=63, reg_lambda=1.8232796195840406, total=  34.2s
# [CV] learning_rate=0.03409976001133041, max_depth=21, min_child_weight=30, n_estimators=63, reg_lambda=1.8232796195840406
# [CV]  learning_rate=0.03409976001133041, max_depth=21, min_child_weight=30, n_estimators=63, reg_lambda=1.8232796195840406, total=  33.8s
# [CV] learning_rate=0.2687985703393734, max_depth=29, min_child_weight=42, n_estimators=294, reg_lambda=2.579718182549386
# [CV]  learning_rate=0.2687985703393734, max_depth=29, min_child_weight=42, n_estimators=294, reg_lambda=2.579718182549386, total= 3.5min
# [CV] learning_rate=0.2687985703393734, max_depth=29, min_child_weight=42, n_estimators=294, reg_lambda=2.579718182549386
# [CV]  learning_rate=0.2687985703393734, max_depth=29, min_child_weight=42, n_estimators=294, reg_lambda=2.579718182549386, total= 3.6min
# [CV] learning_rate=0.2687985703393734, max_depth=29, min_child_weight=42, n_estimators=294, reg_lambda=2.579718182549386
# [CV]  learning_rate=0.2687985703393734, max_depth=29, min_child_weight=42, n_estimators=294, reg_lambda=2.579718182549386, total= 3.6min
# [CV] learning_rate=0.2687985703393734, max_depth=29, min_child_weight=42, n_estimators=294, reg_lambda=2.579718182549386
# [CV]  learning_rate=0.2687985703393734, max_depth=29, min_child_weight=42, n_estimators=294, reg_lambda=2.579718182549386, total= 3.6min
# [CV] learning_rate=0.2687985703393734, max_depth=29, min_child_weight=42, n_estimators=294, reg_lambda=2.579718182549386
# [CV]  learning_rate=0.2687985703393734, max_depth=29, min_child_weight=42, n_estimators=294, reg_lambda=2.579718182549386, total= 3.6min
# [CV] learning_rate=0.04363108998804308, max_depth=18, min_child_weight=18, n_estimators=190, reg_lambda=2.022188551341151
# [CV]  learning_rate=0.04363108998804308, max_depth=18, min_child_weight=18, n_estimators=190, reg_lambda=2.022188551341151, total= 1.6min
# [CV] learning_rate=0.04363108998804308, max_depth=18, min_child_weight=18, n_estimators=190, reg_lambda=2.022188551341151
# [CV]  learning_rate=0.04363108998804308, max_depth=18, min_child_weight=18, n_estimators=190, reg_lambda=2.022188551341151, total= 1.7min
# [CV] learning_rate=0.04363108998804308, max_depth=18, min_child_weight=18, n_estimators=190, reg_lambda=2.022188551341151
# [CV]  learning_rate=0.04363108998804308, max_depth=18, min_child_weight=18, n_estimators=190, reg_lambda=2.022188551341151, total= 1.6min
# [CV] learning_rate=0.04363108998804308, max_depth=18, min_child_weight=18, n_estimators=190, reg_lambda=2.022188551341151
# [CV]  learning_rate=0.04363108998804308, max_depth=18, min_child_weight=18, n_estimators=190, reg_lambda=2.022188551341151, total= 1.6min
# [CV] learning_rate=0.04363108998804308, max_depth=18, min_child_weight=18, n_estimators=190, reg_lambda=2.022188551341151
# [CV]  learning_rate=0.04363108998804308, max_depth=18, min_child_weight=18, n_estimators=190, reg_lambda=2.022188551341151, total= 1.6min
# [CV] learning_rate=0.055488702216194535, max_depth=29, min_child_weight=34, n_estimators=253, reg_lambda=1.4226976205810231
# [CV]  learning_rate=0.055488702216194535, max_depth=29, min_child_weight=34, n_estimators=253, reg_lambda=1.4226976205810231, total= 2.9min
# [CV] learning_rate=0.055488702216194535, max_depth=29, min_child_weight=34, n_estimators=253, reg_lambda=1.4226976205810231
# [CV]  learning_rate=0.055488702216194535, max_depth=29, min_child_weight=34, n_estimators=253, reg_lambda=1.4226976205810231, total= 2.9min
# [CV] learning_rate=0.055488702216194535, max_depth=29, min_child_weight=34, n_estimators=253, reg_lambda=1.4226976205810231
# [CV]  learning_rate=0.055488702216194535, max_depth=29, min_child_weight=34, n_estimators=253, reg_lambda=1.4226976205810231, total= 2.9min
# [CV] learning_rate=0.055488702216194535, max_depth=29, min_child_weight=34, n_estimators=253, reg_lambda=1.4226976205810231
# [CV]  learning_rate=0.055488702216194535, max_depth=29, min_child_weight=34, n_estimators=253, reg_lambda=1.4226976205810231, total= 2.9min
# [CV] learning_rate=0.055488702216194535, max_depth=29, min_child_weight=34, n_estimators=253, reg_lambda=1.4226976205810231
# [CV]  learning_rate=0.055488702216194535, max_depth=29, min_child_weight=34, n_estimators=253, reg_lambda=1.4226976205810231, total= 2.9min
# [CV] learning_rate=0.15928006532221256, max_depth=14, min_child_weight=26, n_estimators=265, reg_lambda=1.7423202537209899
# [CV]  learning_rate=0.15928006532221256, max_depth=14, min_child_weight=26, n_estimators=265, reg_lambda=1.7423202537209899, total= 1.7min
# [CV] learning_rate=0.15928006532221256, max_depth=14, min_child_weight=26, n_estimators=265, reg_lambda=1.7423202537209899
# [CV]  learning_rate=0.15928006532221256, max_depth=14, min_child_weight=26, n_estimators=265, reg_lambda=1.7423202537209899, total= 1.7min
# [CV] learning_rate=0.15928006532221256, max_depth=14, min_child_weight=26, n_estimators=265, reg_lambda=1.7423202537209899
# [CV]  learning_rate=0.15928006532221256, max_depth=14, min_child_weight=26, n_estimators=265, reg_lambda=1.7423202537209899, total= 1.6min
# [CV] learning_rate=0.15928006532221256, max_depth=14, min_child_weight=26, n_estimators=265, reg_lambda=1.7423202537209899
# [CV]  learning_rate=0.15928006532221256, max_depth=14, min_child_weight=26, n_estimators=265, reg_lambda=1.7423202537209899, total= 1.6min
# [CV] learning_rate=0.15928006532221256, max_depth=14, min_child_weight=26, n_estimators=265, reg_lambda=1.7423202537209899
# [CV]  learning_rate=0.15928006532221256, max_depth=14, min_child_weight=26, n_estimators=265, reg_lambda=1.7423202537209899, total= 1.7min
# [CV] learning_rate=0.15699960002109173, max_depth=14, min_child_weight=25, n_estimators=137, reg_lambda=1.0139295096078023
# [CV]  learning_rate=0.15699960002109173, max_depth=14, min_child_weight=25, n_estimators=137, reg_lambda=1.0139295096078023, total=  54.6s
# [CV] learning_rate=0.15699960002109173, max_depth=14, min_child_weight=25, n_estimators=137, reg_lambda=1.0139295096078023
# [CV]  learning_rate=0.15699960002109173, max_depth=14, min_child_weight=25, n_estimators=137, reg_lambda=1.0139295096078023, total=  53.5s
# [CV] learning_rate=0.15699960002109173, max_depth=14, min_child_weight=25, n_estimators=137, reg_lambda=1.0139295096078023
# [CV]  learning_rate=0.15699960002109173, max_depth=14, min_child_weight=25, n_estimators=137, reg_lambda=1.0139295096078023, total=  53.7s
# [CV] learning_rate=0.15699960002109173, max_depth=14, min_child_weight=25, n_estimators=137, reg_lambda=1.0139295096078023
# [CV]  learning_rate=0.15699960002109173, max_depth=14, min_child_weight=25, n_estimators=137, reg_lambda=1.0139295096078023, total=  54.4s
# [CV] learning_rate=0.15699960002109173, max_depth=14, min_child_weight=25, n_estimators=137, reg_lambda=1.0139295096078023
# [CV]  learning_rate=0.15699960002109173, max_depth=14, min_child_weight=25, n_estimators=137, reg_lambda=1.0139295096078023, total=  54.7s
# [CV] learning_rate=0.187354708807717, max_depth=21, min_child_weight=14, n_estimators=228, reg_lambda=0.6133423938385537
# [CV]  learning_rate=0.187354708807717, max_depth=21, min_child_weight=14, n_estimators=228, reg_lambda=0.6133423938385537, total= 2.1min
# [CV] learning_rate=0.187354708807717, max_depth=21, min_child_weight=14, n_estimators=228, reg_lambda=0.6133423938385537
# [CV]  learning_rate=0.187354708807717, max_depth=21, min_child_weight=14, n_estimators=228, reg_lambda=0.6133423938385537, total= 2.1min
# [CV] learning_rate=0.187354708807717, max_depth=21, min_child_weight=14, n_estimators=228, reg_lambda=0.6133423938385537
# [CV]  learning_rate=0.187354708807717, max_depth=21, min_child_weight=14, n_estimators=228, reg_lambda=0.6133423938385537, total= 2.1min
# [CV] learning_rate=0.187354708807717, max_depth=21, min_child_weight=14, n_estimators=228, reg_lambda=0.6133423938385537
# [CV]  learning_rate=0.187354708807717, max_depth=21, min_child_weight=14, n_estimators=228, reg_lambda=0.6133423938385537, total= 2.1min
# [CV] learning_rate=0.187354708807717, max_depth=21, min_child_weight=14, n_estimators=228, reg_lambda=0.6133423938385537
# [CV]  learning_rate=0.187354708807717, max_depth=21, min_child_weight=14, n_estimators=228, reg_lambda=0.6133423938385537, total= 2.0min
# [CV] learning_rate=0.11271199025575147, max_depth=10, min_child_weight=35, n_estimators=263, reg_lambda=0.49761018417150227
# [CV]  learning_rate=0.11271199025575147, max_depth=10, min_child_weight=35, n_estimators=263, reg_lambda=0.49761018417150227, total= 1.3min
# [CV] learning_rate=0.11271199025575147, max_depth=10, min_child_weight=35, n_estimators=263, reg_lambda=0.49761018417150227
# [CV]  learning_rate=0.11271199025575147, max_depth=10, min_child_weight=35, n_estimators=263, reg_lambda=0.49761018417150227, total= 1.3min
# [CV] learning_rate=0.11271199025575147, max_depth=10, min_child_weight=35, n_estimators=263, reg_lambda=0.49761018417150227
# [CV]  learning_rate=0.11271199025575147, max_depth=10, min_child_weight=35, n_estimators=263, reg_lambda=0.49761018417150227, total= 1.3min
# [CV] learning_rate=0.11271199025575147, max_depth=10, min_child_weight=35, n_estimators=263, reg_lambda=0.49761018417150227
# [CV]  learning_rate=0.11271199025575147, max_depth=10, min_child_weight=35, n_estimators=263, reg_lambda=0.49761018417150227, total= 1.3min
# [CV] learning_rate=0.11271199025575147, max_depth=10, min_child_weight=35, n_estimators=263, reg_lambda=0.49761018417150227
# [CV]  learning_rate=0.11271199025575147, max_depth=10, min_child_weight=35, n_estimators=263, reg_lambda=0.49761018417150227, total= 1.3min
# [CV] learning_rate=0.21717612757854568, max_depth=10, min_child_weight=43, n_estimators=261, reg_lambda=1.7687238816210988
# [CV]  learning_rate=0.21717612757854568, max_depth=10, min_child_weight=43, n_estimators=261, reg_lambda=1.7687238816210988, total= 1.3min
# [CV] learning_rate=0.21717612757854568, max_depth=10, min_child_weight=43, n_estimators=261, reg_lambda=1.7687238816210988
# [CV]  learning_rate=0.21717612757854568, max_depth=10, min_child_weight=43, n_estimators=261, reg_lambda=1.7687238816210988, total= 1.2min
# [CV] learning_rate=0.21717612757854568, max_depth=10, min_child_weight=43, n_estimators=261, reg_lambda=1.7687238816210988
# [CV]  learning_rate=0.21717612757854568, max_depth=10, min_child_weight=43, n_estimators=261, reg_lambda=1.7687238816210988, total= 1.2min
# [CV] learning_rate=0.21717612757854568, max_depth=10, min_child_weight=43, n_estimators=261, reg_lambda=1.7687238816210988
# [CV]  learning_rate=0.21717612757854568, max_depth=10, min_child_weight=43, n_estimators=261, reg_lambda=1.7687238816210988, total= 1.3min
# [CV] learning_rate=0.21717612757854568, max_depth=10, min_child_weight=43, n_estimators=261, reg_lambda=1.7687238816210988
# [CV]  learning_rate=0.21717612757854568, max_depth=10, min_child_weight=43, n_estimators=261, reg_lambda=1.7687238816210988, total= 1.3min
# [CV] learning_rate=0.16560734289085685, max_depth=17, min_child_weight=41, n_estimators=137, reg_lambda=1.8937028833352159
# [CV]  learning_rate=0.16560734289085685, max_depth=17, min_child_weight=41, n_estimators=137, reg_lambda=1.8937028833352159, total= 1.1min
# [CV] learning_rate=0.16560734289085685, max_depth=17, min_child_weight=41, n_estimators=137, reg_lambda=1.8937028833352159
# [CV]  learning_rate=0.16560734289085685, max_depth=17, min_child_weight=41, n_estimators=137, reg_lambda=1.8937028833352159, total= 1.1min
# [CV] learning_rate=0.16560734289085685, max_depth=17, min_child_weight=41, n_estimators=137, reg_lambda=1.8937028833352159
# [CV]  learning_rate=0.16560734289085685, max_depth=17, min_child_weight=41, n_estimators=137, reg_lambda=1.8937028833352159, total= 1.0min
# [CV] learning_rate=0.16560734289085685, max_depth=17, min_child_weight=41, n_estimators=137, reg_lambda=1.8937028833352159
# [CV]  learning_rate=0.16560734289085685, max_depth=17, min_child_weight=41, n_estimators=137, reg_lambda=1.8937028833352159, total=  57.8s
# [CV] learning_rate=0.16560734289085685, max_depth=17, min_child_weight=41, n_estimators=137, reg_lambda=1.8937028833352159
# [CV]  learning_rate=0.16560734289085685, max_depth=17, min_child_weight=41, n_estimators=137, reg_lambda=1.8937028833352159, total=  59.5s
# [CV] learning_rate=0.12203041197354063, max_depth=10, min_child_weight=30, n_estimators=124, reg_lambda=1.4039970504383343
# [CV]  learning_rate=0.12203041197354063, max_depth=10, min_child_weight=30, n_estimators=124, reg_lambda=1.4039970504383343, total=  38.3s
# [CV] learning_rate=0.12203041197354063, max_depth=10, min_child_weight=30, n_estimators=124, reg_lambda=1.4039970504383343
# [CV]  learning_rate=0.12203041197354063, max_depth=10, min_child_weight=30, n_estimators=124, reg_lambda=1.4039970504383343, total=  38.1s
# [CV] learning_rate=0.12203041197354063, max_depth=10, min_child_weight=30, n_estimators=124, reg_lambda=1.4039970504383343
# [CV]  learning_rate=0.12203041197354063, max_depth=10, min_child_weight=30, n_estimators=124, reg_lambda=1.4039970504383343, total=  36.6s
# [CV] learning_rate=0.12203041197354063, max_depth=10, min_child_weight=30, n_estimators=124, reg_lambda=1.4039970504383343
# [CV]  learning_rate=0.12203041197354063, max_depth=10, min_child_weight=30, n_estimators=124, reg_lambda=1.4039970504383343, total=  36.0s
# [CV] learning_rate=0.12203041197354063, max_depth=10, min_child_weight=30, n_estimators=124, reg_lambda=1.4039970504383343
# [CV]  learning_rate=0.12203041197354063, max_depth=10, min_child_weight=30, n_estimators=124, reg_lambda=1.4039970504383343, total=  36.6s
# [CV] learning_rate=0.07596924731114152, max_depth=12, min_child_weight=16, n_estimators=299, reg_lambda=0.6899572015209755
# [CV]  learning_rate=0.07596924731114152, max_depth=12, min_child_weight=16, n_estimators=299, reg_lambda=0.6899572015209755, total= 1.7min
# [CV] learning_rate=0.07596924731114152, max_depth=12, min_child_weight=16, n_estimators=299, reg_lambda=0.6899572015209755
# [CV]  learning_rate=0.07596924731114152, max_depth=12, min_child_weight=16, n_estimators=299, reg_lambda=0.6899572015209755, total= 1.7min
# [CV] learning_rate=0.07596924731114152, max_depth=12, min_child_weight=16, n_estimators=299, reg_lambda=0.6899572015209755
# [CV]  learning_rate=0.07596924731114152, max_depth=12, min_child_weight=16, n_estimators=299, reg_lambda=0.6899572015209755, total= 1.7min
# [CV] learning_rate=0.07596924731114152, max_depth=12, min_child_weight=16, n_estimators=299, reg_lambda=0.6899572015209755
# [CV]  learning_rate=0.07596924731114152, max_depth=12, min_child_weight=16, n_estimators=299, reg_lambda=0.6899572015209755, total= 1.7min
# [CV] learning_rate=0.07596924731114152, max_depth=12, min_child_weight=16, n_estimators=299, reg_lambda=0.6899572015209755
# [CV]  learning_rate=0.07596924731114152, max_depth=12, min_child_weight=16, n_estimators=299, reg_lambda=0.6899572015209755, total= 1.7min
# [CV] learning_rate=0.02862058526389793, max_depth=14, min_child_weight=49, n_estimators=293, reg_lambda=0.18948181509476916
# [CV]  learning_rate=0.02862058526389793, max_depth=14, min_child_weight=49, n_estimators=293, reg_lambda=0.18948181509476916, total= 1.9min
# [CV] learning_rate=0.02862058526389793, max_depth=14, min_child_weight=49, n_estimators=293, reg_lambda=0.18948181509476916
# [CV]  learning_rate=0.02862058526389793, max_depth=14, min_child_weight=49, n_estimators=293, reg_lambda=0.18948181509476916, total= 2.0min
# [CV] learning_rate=0.02862058526389793, max_depth=14, min_child_weight=49, n_estimators=293, reg_lambda=0.18948181509476916
# [CV]  learning_rate=0.02862058526389793, max_depth=14, min_child_weight=49, n_estimators=293, reg_lambda=0.18948181509476916, total= 1.9min
# [CV] learning_rate=0.02862058526389793, max_depth=14, min_child_weight=49, n_estimators=293, reg_lambda=0.18948181509476916
# [CV]  learning_rate=0.02862058526389793, max_depth=14, min_child_weight=49, n_estimators=293, reg_lambda=0.18948181509476916, total= 1.9min
# [CV] learning_rate=0.02862058526389793, max_depth=14, min_child_weight=49, n_estimators=293, reg_lambda=0.18948181509476916
# [CV]  learning_rate=0.02862058526389793, max_depth=14, min_child_weight=49, n_estimators=293, reg_lambda=0.18948181509476916, total= 2.0min
# [CV] learning_rate=0.3055615200425138, max_depth=14, min_child_weight=26, n_estimators=296, reg_lambda=1.3989684162510585
# [CV]  learning_rate=0.3055615200425138, max_depth=14, min_child_weight=26, n_estimators=296, reg_lambda=1.3989684162510585, total= 1.8min
# [CV] learning_rate=0.3055615200425138, max_depth=14, min_child_weight=26, n_estimators=296, reg_lambda=1.3989684162510585
# [CV]  learning_rate=0.3055615200425138, max_depth=14, min_child_weight=26, n_estimators=296, reg_lambda=1.3989684162510585, total= 1.9min
# [CV] learning_rate=0.3055615200425138, max_depth=14, min_child_weight=26, n_estimators=296, reg_lambda=1.3989684162510585
# [CV]  learning_rate=0.3055615200425138, max_depth=14, min_child_weight=26, n_estimators=296, reg_lambda=1.3989684162510585, total= 1.9min
# [CV] learning_rate=0.3055615200425138, max_depth=14, min_child_weight=26, n_estimators=296, reg_lambda=1.3989684162510585
# [CV]  learning_rate=0.3055615200425138, max_depth=14, min_child_weight=26, n_estimators=296, reg_lambda=1.3989684162510585, total= 1.9min
# [CV] learning_rate=0.3055615200425138, max_depth=14, min_child_weight=26, n_estimators=296, reg_lambda=1.3989684162510585
# [CV]  learning_rate=0.3055615200425138, max_depth=14, min_child_weight=26, n_estimators=296, reg_lambda=1.3989684162510585, total= 1.9min
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed: 230.9min finished
# 0.7367767244197451 {'learning_rate': 0.02862058526389793, 'max_depth': 14, 'min_child_weight': 49, 'n_estimators': 293, 'reg_lambda': 0.18948181509476916}
# ['best_xgboost.joblib']

# %%
best_logistic_regression = joblib.load("data/best_logisticregression.joblib")
best_xgbclassifier = joblib.load("data/best_xgbclassifier.joblib")
print(f"Accuracy score for Logistic Regression: {accuracy_score(best_logistic_regression.predict(X_val_lda),y_val)}")
print(f"Accuracy score for XGBoostClassifier: {accuracy_score(best_xgbclassifier.predict(X_val_lda),y_val)}")
# Out:
# Accuracy score for Logistic Regression: 0.6726381170317097
# Accuracy score for XGBoostClassifier: 0.7367767244197451

# %% [markdown]
# ### LSTM

# %% [markdown]
# #### Text preprocessing for LSTM

# %%
# reapplying split on X
X_train, X_test= train_test_split(X, test_size=0.15, 
                                                          random_state=42)
X_train, X_val= train_test_split(X_train, test_size=0.15, 
                                                          random_state=52)

# tokenizing and filtering out basic punctuation and setting to lowercase
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# dictionary mapping words (str) to their index (int)
word_index = tokenizer.word_index
print(f"Found {len(word_index)} unique tokens.")
print(word_index)

# turning texts into sequences (list of word indexes)
sequences_train = tokenizer.texts_to_sequences(X_train)
sequences_test = tokenizer.texts_to_sequences(X_test)
sequences_val = tokenizer.texts_to_sequences(X_val)

# checking the length of the longest review
max_len = max([len(x) for x in sequences_train+sequences_val+sequences_test])
print(f"The longest description has {max_len} words.")

# padding sequences so that they are of equal length
X_train_nn = sequence.pad_sequences(sequences_train, max_len)
X_test_nn = sequence.pad_sequences(sequences_test, max_len)
X_val_nn = sequence.pad_sequences(sequences_val, max_len)
# Out:
# Found 32524 unique tokens.
# {'and': 1, 'the': 2, 'a': 3, 'of': 4, 'with': 5, 'this': 6, 'is': 7, 'wine': 8, 'in': 9, 'flavors': 10, 'to': 11, 'it': 12, 'fruit': 13, 'on': 14, 'aromas': 15, 'palate': 16, 'that': 17, 'acidity': 18, 'finish': 19, 'from': 20, 'but': 21, 'tannins': 22, "it's": 23, 'drink': 24, 'cherry': 25, 'black': 26, 'ripe': 27, 'are': 28, 'has': 29, 'for': 30, 'red': 31, 'by': 32, 'spice': 33, 'notes': 34, 'an': 35, 'as': 36, 'its': 37, 'oak': 38, 'rich': 39, 'fresh': 40, 'dry': 41, 'berry': 42, 'nose': 43, 'full': 44, 'now': 45, 'plum': 46, 'sweet': 47, 'soft': 48, 'fruits': 49, 'apple': 50, 'well': 51, 'blend': 52, 'blackberry': 53, 'crisp': 54, 'white': 55, 'offers': 56, 'light': 57, 'texture': 58, 'dark': 59, 'citrus': 60, 'shows': 61, 'while': 62, 'through': 63, 'bodied': 64, 'vanilla': 65, 'bright': 66, 'cabernet': 67, 'at': 68, 'very': 69, 'more': 70, 'pepper': 71, 'green': 72, 'good': 73, 'juicy': 74, 'lemon': 75, 'fruity': 76, 'raspberry': 77, 'firm': 78, 'some': 79, 'chocolate': 80, 'peach': 81, 'balanced': 82, 'touch': 83, 'character': 84, 'like': 85, 'not': 86, 'will': 87, 'dried': 88, 'pear': 89, 'out': 90, 'years': 91, 'up': 92, 'or': 93, 'sauvignon': 94, 'structure': 95, 'spicy': 96, 'be': 97, 'fine': 98, 'smooth': 99, 'all': 100, 'wood': 101, 'made': 102, 'pinot': 103, 'medium': 104, 'currant': 105, 'mouth': 106, 'long': 107, 'style': 108, 'herb': 109, 'just': 110, 'concentrated': 111, 'mineral': 112, 'into': 113, 'tart': 114, 'tannic': 115, 'herbal': 116, 'also': 117, 'there': 118, 'vineyard': 119, 'flavor': 120, 'note': 121, 'merlot': 122, 'licorice': 123, 'hint': 124, 'lime': 125, 'still': 126, 'bit': 127, 'clean': 128, 'age': 129, 'creamy': 130, "there's": 131, 'orange': 132, 'so': 133, 'toast': 134, 'give': 135, 'one': 136, 'opens': 137, 'balance': 138, 'aging': 139, 'syrah': 140, 'dense': 141, 'over': 142, 'structured': 143, 'along': 144, 'leather': 145, 'tobacco': 146, 'savory': 147, 'alongside': 148, 'delicious': 149, 'earthy': 150, 'ready': 151, 'lead': 152, 'tight': 153, 'slightly': 154, 'which': 155, 'elegant': 156, 'great': 157, 'hints': 158, 'easy': 159, 'complex': 160, 'than': 161, 'mouthfeel': 162, 'chardonnay': 163, 'yet': 164, 'new': 165, 'richness': 166, 'cassis': 167, 'freshness': 168, 'time': 169, 'smoky': 170, 'young': 171, 'herbs': 172, 'cherries': 173, 'vintage': 174, 'lively': 175, 'cola': 176, 'yellow': 177, 'strawberry': 178, 'grapefruit': 179, 'honey': 180, 'color': 181, 'delivers': 182, 'coffee': 183, 'feels': 184, 'feel': 185, 'big': 186, 'melon': 187, 'high': 188, 'little': 189, 'almost': 190, 'you': 191, 'stone': 192, 'wild': 193, 'clove': 194, 'simple': 195, 'weight': 196, 'off': 197, 'pineapple': 198, 'intense': 199, 'solid': 200, 'earth': 201, 'tastes': 202, 'barrel': 203, 'tropical': 204, 'apricot': 205, 'come': 206, 'attractive': 207, 'floral': 208, 'cinnamon': 209, 'round': 210, 'best': 211, 'bottling': 212, "that's": 213, 'refreshing': 214, 'core': 215, 'showing': 216, 'finishes': 217, 'should': 218, 'alcohol': 219, 'minerality': 220, 'baked': 221, 'lightly': 222, 'show': 223, 'complexity': 224, 'edge': 225, 'plenty': 226, 'gives': 227, 'tangy': 228, 'generous': 229, 'scents': 230, 'pretty': 231, 'make': 232, 'noir': 233, 'bitter': 234, 'quite': 235, 'toasty': 236, 'crushed': 237, 'comes': 238, 'zest': 239, 'cranberry': 240, 'glass': 241, 'body': 242, 'blueberry': 243, 'drinking': 244, 'much': 245, 'cedar': 246, 'silky': 247, '2018': 248, 'grapes': 249, 'smoke': 250, 'textured': 251, 'flower': 252, 'aged': 253, 'spices': 254, 'concentration': 255, 'toasted': 256, 'strong': 257, 'mocha': 258, 'almond': 259, 'perfumed': 260, 'blanc': 261, 'franc': 262, 'powerful': 263, 'mature': 264, 'wines': 265, 'oaky': 266, 'aftertaste': 267, 'delicate': 268, 'jammy': 269, 'zesty': 270, 'have': 271, 'nice': 272, 'roasted': 273, 'after': 274, 'bottle': 275, 'rounded': 276, 'tones': 277, 'aromatic': 278, 'too': 279, 'layers': 280, 'followed': 281, 'although': 282, 'here': 283, 'end': 284, 'warm': 285, ' ...
# The longest description has 136 words.

# %%
# turning y into one-hots
nb_classes=3
y_train = np_utils.to_categorical(y_train, nb_classes)
y_test = np_utils.to_categorical(y_test, nb_classes)
y_val = np_utils.to_categorical(y_val, nb_classes)

# %% [markdown]
# #### Preparing pre-trained Embeddings

# %% [markdown]
# I will use pre-trained Glove embeddings.
#
# First I loaded the smallest Glove Embedding  model with 400 000 embeddings. As wines descriptions include some not-so-common word I checked if the vocabulary of the model is not to small. 68% of the vocabulary from wine reviews is coverd in the smallest Glove Model. So I tried bigger models. Best coverage was for the model with 1,9 M vocabulary - 75%. It's not perfect, but I will give it a try.

# %%
# code to download, unzip, preprocess and load pre-trained Glove model with embeddings
# I saved an array of filetered embeddings and load it below 

# !wget http://nlp.stanford.edu/data/glove.42B.300d.zip
# !unzip glove.42B.300d.zip

def load_glove_model(glove_input_file, word2vec_output_file="/final_project/gensim_glove_vectors.txt"):
  glove2word2vec(glove_input_file, word2vec_output_file)
  return KeyedVectors.load_word2vec_format(word2vec_output_file, binary=False)
glove_model = load_glove_model("glove.42B.300d.txt")

# creating embedding matrix containing only embeddings for words used in wines reviews

emb_matrix = np.zeros((len(word_index), 300))
for w, i in word_index.items():
  try:
    vect = glove_model[w]
    if vect is not None:
      emb_matrix[i] = vect
  except:
    pass

joblib.dump(emb_matrix, "emb_matrix.joblib")

# %%
# checking how many words from wines reviews are reprezented in pre-trained Glove Embeddings
print(len(([key for key in word_index.keys() if key in glove_model]))/len(word_index))
# Out:
# 0.7513528471282745

# %%
emb_matrix = joblib.load("data/emb_matrix.joblib")

# %% [markdown]
# #### Learning model

# %% [markdown]
# Now prepared texts and embeddings can be fed into Neural Network. I test several architectures for LSTM network.

# %%
def build_lstm_model_1(list_of_layers):
  
  model = Sequential()
  model.add(Embedding(emb_matrix.shape[0],
                      emb_matrix.shape[1], 
                      input_length=max_len,
                      weights = [emb_matrix], 
                      trainable = False))
  for layer in list_of_layers:
    model.add(layer)
  model.summary() 
  
  model.compile(loss="categorical_crossentropy",
               optimizer="adam", 
               metrics=["categorical_accuracy"])
  return model

# %%
def evaluate_lstm_model(model, X_train, X_val, y_train, y_val, filename, batch_size=128):

  early_stopping = EarlyStopping(patience=3, monitor="val_loss")
  take_best_model = ModelCheckpoint(str(filename)+".h5py", save_best_only=True)

  model.fit(X_train, y_train, epochs=100, validation_split=0.2,
           batch_size=batch_size, 
           callbacks=[early_stopping, take_best_model])

  model.load_weights(str(filename)+".h5py")
  return model.evaluate(X_val, y_val)[1]

# %%
models = {        
          "clf_LSTM_300n":      [LSTM(300),
                                  Dense(3, activation="softmax")],
    
          "clf_LSTM_500n":      [LSTM(500),
                                  Dense(3, activation="softmax")],
    
          "clf_LSTM_1000n":      [LSTM(1000),
                                  Dense(3, activation="softmax")],
          
          "clf_BiLSTM_Dense":          [Bidirectional(LSTM(100)),
                                  Dense(3, activation="softmax")],
          
          "clf_MultipleLSTM_Dense":    [LSTM(200, return_sequences=True),
                                  LSTM(100),
                                  Dense(3, activation="softmax")],
          
          "clf_LSTM_MultipleDense":     [LSTM(100),
                                  Dense(30, activation="relu"),
                                  Dense(3, activation="softmax")],
     
         
          "clf_Conv_Pool_LSTM_Dense": [Conv1D(32,3),
                                   MaxPooling1D(pool_size=2),
                                   LSTM(100),
                                   Dense(3, activation="softmax")],
}

# %%
lst = []
for model, params in models.items():
  acc = (evaluate_lstm_model(build_lstm_model_1(params), X_train_nn, X_val_nn, y_train, y_val, model))
  lst.append(acc)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 300)               721200
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 903
# =================================================================
# Total params: 10,479,303
# Trainable params: 722,103
# Non-trainable params: 9,757,200
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 158s 2ms/step - loss: 0.5252 - categorical_accuracy: 0.7703 - val_loss: 0.4750 - val_categorical_accuracy: 0.7872
# Epoch 2/100
# 69332/69332 [==============================] - 157s 2ms/step - loss: 0.4417 - categorical_accuracy: 0.8089 - val_loss: 0.4498 - val_categorical_accuracy: 0.8003
# Epoch 3/100
# 69332/69332 [==============================] - 157s 2ms/step - loss: 0.4086 - categorical_accuracy: 0.8211 - val_loss: 0.4325 - val_categorical_accuracy: 0.8126
# Epoch 4/100
# 69332/69332 [==============================] - 156s 2ms/step - loss: 0.3792 - categorical_accuracy: 0.8359 - val_loss: 0.4239 - val_categorical_accuracy: 0.8174
# Epoch 5/100
# 69332/69332 [==============================] - 157s 2ms/step - loss: 0.3472 - categorical_accuracy: 0.8509 - val_loss: 0.4297 - val_categorical_accuracy: 0.8138
# Epoch 6/100
# 69332/69332 [==============================] - 157s 2ms/step - loss: 0.3053 - categorical_accuracy: 0.8696 - val_loss: 0.4675 - val_categorical_accuracy: 0.8107
# Epoch 7/100
# 69332/69332 [==============================] - 157s 2ms/step - loss: 0.2534 - categorical_accuracy: 0.8940 - val_loss: 0.5003 - val_categorical_accuracy: 0.8039
# 15295/15295 [==============================] - 54s 4ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 500)               1602000
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 1503
# =================================================================
# Total params: 11,360,703
# Trainable params: 1,603,503
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 201s 3ms/step - loss: 0.5321 - categorical_accuracy: 0.7673 - val_loss: 0.4715 - val_categorical_accuracy: 0.7989
# Epoch 2/100
# 69332/69332 [==============================] - 199s 3ms/step - loss: 0.4427 - categorical_accuracy: 0.8075 - val_loss: 0.4467 - val_categorical_accuracy: 0.8049
# Epoch 3/100
# 69332/69332 [==============================] - 199s 3ms/step - loss: 0.4095 - categorical_accuracy: 0.8230 - val_loss: 0.4295 - val_categorical_accuracy: 0.8116
# Epoch 4/100
# 69332/69332 [==============================] - 199s 3ms/step - loss: 0.3790 - categorical_accuracy: 0.8364 - val_loss: 0.4390 - val_categorical_accuracy: 0.8128
# Epoch 5/100
# 69332/69332 [==============================] - 199s 3ms/step - loss: 0.3423 - categorical_accuracy: 0.8521 - val_loss: 0.4361 - val_categorical_accuracy: 0.8120
# Epoch 6/100
# 69332/69332 [==============================] - 199s 3ms/step - loss: 0.2896 - categorical_accuracy: 0.8775 - val_loss: 0.4629 - val_categorical_accuracy: 0.8111
# 15295/15295 [==============================] - 54s 4ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 1000)              5204000
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 3003
# =================================================================
# Total params: 14,964,203
# Trainable params: 5,207,003
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 400s 6ms/step - loss: 0.6019 - categorical_accuracy: 0.7384 - val_loss: 0.4791 - val_categorical_accuracy: 0.7892
# Epoch 2/100
# 69332/69332 [==============================] - 398s 6ms/step - loss: 0.4543 - categorical_accuracy: 0.8026 - val_loss: 0.4448 - val_categorical_accuracy: 0.8069
# Epoch 3/100
# 69332/69332 [==============================] - 398s 6ms/step - loss: 0.4228 - categorical_accuracy: 0.8154 - val_loss: 0.4419 - val_categorical_accuracy: 0.8047
# Epoch 4/100
# 69332/69332 [==============================] - 399s 6ms/step - loss: 0.3902 - categorical_accuracy: 0.8296 - val_loss: 0.4272 - val_categorical_accuracy: 0.8165
# Epoch 5/100
# 69332/69332 [==============================] - 403s 6ms/step - loss: 0.3579 - categorical_accuracy: 0.8447 - val_loss: 0.4385 - val_categorical_accuracy: 0.8149
# Epoch 6/100
# 69332/69332 [==============================] - 404s 6ms/step - loss: 0.3082 - categorical_accuracy: 0.8696 - val_loss: 0.4486 - val_categorical_accuracy: 0.8109
# Epoch 7/100
# 69332/69332 [==============================] - 404s 6ms/step - loss: 0.2377 - categorical_accuracy: 0.9015 - val_loss: 0.5194 - val_categorical_accuracy: 0.8066
# 15295/15295 [==============================] - 82s 5ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 200)               320800
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 603
# =================================================================
# Total params: 10,078,603
# Trainable params: 321,403
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 316s 5ms/step - loss: 0.5322 - categorical_accuracy: 0.7693 - val_loss: 0.4769 - val_categorical_accuracy: 0.7901
# Epoch 2/100
# 69332/69332 [==============================] - 313s 5ms/step - loss: 0.4507 - categorical_accuracy: 0.8044 - val_loss: 0.4550 - val_categorical_accuracy: 0.7993
# Epoch 3/100
# 69332/69332 [==============================] - 308s 4ms/step - loss: 0.4209 - categorical_accuracy: 0.8168 - val_loss: 0.4358 - val_categorical_accuracy: 0.8098
# Epoch 4/100
# 69332/69332 [==============================] - 306s 4ms/step - loss: 0.3974 - categorical_accuracy: 0.8269 - val_loss: 0.4268 - val_categorical_accuracy: 0.8160
# Epoch 5/100
# 69332/69332 [==============================] - 304s 4ms/step - loss: 0.3732 - categorical_accuracy: 0.8385 - val_loss: 0.4651 - val_categorical_accuracy: 0.7969
# Epoch 6/100
# 69332/69332 [==============================] - 302s 4ms/step - loss: 0.3515 - categorical_accuracy: 0.8488 - val_loss: 0.4281 - val_categorical_accuracy: 0.8126
# Epoch 7/100
# 69332/69332 [==============================] - 302s 4ms/step - loss: 0.3268 - categorical_accuracy: 0.8594 - val_loss: 0.4438 - val_categorical_accuracy: 0.8150
# 15295/15295 [==============================] - 92s 6ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 136, 200)          400800
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 100)               120400
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 10,278,703
# Trainable params: 521,503
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 284s 4ms/step - loss: 0.5221 - categorical_accuracy: 0.7736 - val_loss: 0.4630 - val_categorical_accuracy: 0.7988
# Epoch 2/100
# 69332/69332 [==============================] - 281s 4ms/step - loss: 0.4421 - categorical_accuracy: 0.8078 - val_loss: 0.4568 - val_categorical_accuracy: 0.7988
# Epoch 3/100
# 69332/69332 [==============================] - 279s 4ms/step - loss: 0.4077 - categorical_accuracy: 0.8232 - val_loss: 0.4251 - val_categorical_accuracy: 0.8142
# Epoch 4/100
# 69332/69332 [==============================] - 280s 4ms/step - loss: 0.3808 - categorical_accuracy: 0.8352 - val_loss: 0.4248 - val_categorical_accuracy: 0.8159
# Epoch 5/100
# 69332/69332 [==============================] - 282s 4ms/step - loss: 0.3492 - categorical_accuracy: 0.8485 - val_loss: 0.4377 - val_categorical_accuracy: 0.8082
# Epoch 6/100
# 69332/69332 [==============================] - 281s 4ms/step - loss: 0.3115 - categorical_accuracy: 0.8674 - val_loss: 0.4482 - val_categorical_accuracy: 0.8103
# Epoch 7/100
# 69332/69332 [==============================] - 283s 4ms/step - loss: 0.2637 - categorical_accuracy: 0.8884 - val_loss: 0.5104 - val_categorical_accuracy: 0.7980
# 15295/15295 [==============================] - 94s 6ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 100)               160400
# _________________________________________________________________
# dense_6 (Dense)              (None, 30)                3030
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 93
# =================================================================
# Total params: 9,920,723
# Trainable params: 163,523
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 142s 2ms/step - loss: 0.5374 - categorical_accuracy: 0.7645 - val_loss: 0.4687 - val_categorical_accuracy: 0.7966
# Epoch 2/100
# 69332/69332 [==============================] - 139s 2ms/step - loss: 0.4500 - categorical_accuracy: 0.8039 - val_loss: 0.4520 - val_categorical_accuracy: 0.8015
# Epoch 3/100
# 69332/69332 [==============================] - 143s 2ms/step - loss: 0.4221 - categorical_accuracy: 0.8162 - val_loss: 0.4419 - val_categorical_accuracy: 0.8072
# Epoch 4/100
# 69332/69332 [==============================] - 140s 2ms/step - loss: 0.3964 - categorical_accuracy: 0.8278 - val_loss: 0.4261 - val_categorical_accuracy: 0.8163
# Epoch 5/100
# 69332/69332 [==============================] - 141s 2ms/step - loss: 0.3744 - categorical_accuracy: 0.8366 - val_loss: 0.4330 - val_categorical_accuracy: 0.8169
# Epoch 6/100
# 69332/69332 [==============================] - 140s 2ms/step - loss: 0.3516 - categorical_accuracy: 0.8464 - val_loss: 0.4499 - val_categorical_accuracy: 0.8068
# Epoch 7/100
# 69332/69332 [==============================] - 141s 2ms/step - loss: 0.3277 - categorical_accuracy: 0.8589 - val_loss: 0.4411 - val_categorical_accuracy: 0.8143
# 15295/15295 [==============================] - 50s 3ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 134, 32)           28832
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 67, 32)            0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 100)               53200
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 9,839,535
# Trainable params: 82,335
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 86s 1ms/step - loss: 0.5340 - categorical_accuracy: 0.7693 - val_loss: 0.4831 - val_categorical_accuracy: 0.7896
# Epoch 2/100
# 69332/69332 [==============================] - 81s 1ms/step - loss: 0.4655 - categorical_accuracy: 0.7984 - val_loss: 0.4723 - val_categorical_accuracy: 0.7910
# Epoch 3/100
# 69332/69332 [==============================] - 82s 1ms/step - loss: 0.4420 - categorical_accuracy: 0.8091 - val_loss: 0.4529 - val_categorical_accuracy: 0.8011
# Epoch 4/100
# 69332/69332 [==============================] - 81s 1ms/step - loss: 0.4195 - categorical_accuracy: 0.8177 - val_loss: 0.4505 - val_categorical_accuracy: 0.8036
# Epoch 5/100
# 69332/69332 [==============================] - 81s 1ms/step - loss: 0.4047 - categorical_accuracy: 0.8238 - val_loss: 0.4498 - val_categorical_accuracy: 0.8039
# Epoch 6/100
# 69332/69332 [==============================] - 81s 1ms/step - loss: 0.3905 - categorical_accuracy: 0.8319 - val_loss: 0.4463 - val_categorical_accuracy: 0.8074
# Epoch 7/100
# 69332/69332 [==============================] - 81s 1ms/step - loss: 0.3708 - categorical_accuracy: 0.8400 - val_loss: 0.4639 - val_categorical_accuracy: 0.8008
# Epoch 8/100
# 69332/69332 [==============================] - 81s 1ms/step - loss: 0.3576 - categorical_accuracy: 0.8455 - val_loss: 0.4684 - val_categorical_accuracy: 0.8026
# Epoch 9/100
# 69332/69332 [==============================] - 80s 1ms/step - loss: 0.3405 - categorical_accuracy: 0.8544 - val_loss: 0.4751 - val_categorical_accuracy: 0.8020
# 15295/15295 [==============================] - 24s 2ms/step

# %%
lstm_1_results = pd.DataFrame(list(zip(models.keys(), lst)), columns=["model", "accuracy"]).sort_values(by="accuracy", ascending=False).reset_index(drop=True)
print(lstm_1_results)

# %%
lstm_1_results
# Out:
#                       model  accuracy
# 0    clf_LSTM_MultipleDense  0.818830
# 1             clf_LSTM_300n  0.817980
# 2            clf_LSTM_1000n  0.817914
# 3    clf_MultipleLSTM_Dense  0.817784
# 4          clf_BiLSTM_Dense  0.817522
# 5             clf_LSTM_500n  0.816999
# 6  clf_Conv_Pool_LSTM_Dense  0.808500

# %% [markdown]
# ### Score on test set

# %% [markdown]
# The best model of all models tested for nominal classification is neural network with LSTM layer with 100 neurons, Dense layer with 30 neurons and output Dense layer. Let's check how it scores on test set.

# %%
# loading best model from a file and evaluating on test set

best_nom_clf = build_lstm_model_1(models["clf_LSTM_MultipleDense"])
best_nom_clf.load_weights("data/best_nn_nom_clf.h5py")
best_nom_clf.compile(loss="categorical_crossentropy",
               optimizer="adam", 
               metrics=["categorical_accuracy"])
best_nom_acc = best_nom_clf.evaluate(X_test_nn, y_test)[1]
print(f"Accuracy of best model for nominal classification: {best_nom_acc}")
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 100)               160400
# _________________________________________________________________
# dense_14 (Dense)             (None, 30)                3030
# _________________________________________________________________
# dense_15 (Dense)             (None, 3)                 93
# =================================================================
# Total params: 9,920,723
# Trainable params: 163,523
# Non-trainable params: 9,757,200
# _________________________________________________________________
# 17994/17994 [==============================] - 65s 4ms/step
# Accuracy of best model for nominal classification: 0.820162276320952

# %% [markdown]
# ## Ordinal Classification

# %% [markdown]
# 1) ordinal classification model: y (points) binned into 3 classes and treated as ordinal variable
#
# Taking into account that winemag.com publishes only reviews of wines over 80 points, classes in this approach could be understood as follows: 0 - average, 1- good, 2 - excellent.

# %% [markdown]
# ### Logistic Regression using mord package

# %% [markdown]
# My first approach will be to use mord package, which "is a Python package that implements some ordinal regression methods following the scikit-learn API." (*mord 0.3 documentation*). I will use mord implementation of Logistic Regression for ordinal classification. The only hyperparameter that can be tuned is alpha, which is L2 regularization parameter.

# %%
param = {"alpha": [0.01, 0.1, 0.3, 0.5, 0.7, 0.9]}
gs = GridSearchCV(mord.LogisticIT(), param, cv=5, scoring="accuracy")
gs.fit(X_train_lda, y_train)
y_pred = gs.best_estimator_.predict(X_val_lda)
print("Ordinal Logistic Regression:")
print(f"Best regularization parameter: {gs.best_params_}")
print(f"Accuracy score: {accuracy_score(y_val, y_pred)}")
# Out:
# Ordinal Logistic Regression:
# Best regularization parameter: {'alpha': 0.01}
# Accuracy score: 0.6726381170317097

# %% [markdown]
# That's an interesting result. Ordinal Logistic Regression scored exacty the same as Logistic Regression for nominal classification. It is most probably coincidence but it shows that mord implementaction of Ordinal Logistic Regression doesn't improve the results. Maybe due to the lack of hyperparameters to tune.

# %% [markdown]
# ### NNRank

# %% [markdown]
# I build neural network architecture for ordinal classification (NNRank) basing on "A Neural Network Approach to Ordinal Regression" J.Chen, Z.Wang, G.Pollastri. Most important differences from standard neural network for classification include:
#
# - **target vector encoding:** "If a data point x belongs to category k, it is classified
# automatically into lower-order categories (1, 2, ..., k − 1) as
# well. So the target vector of x is t = (1, 1, .., 1, 0, 0, 0),
# where ti (1 ≤ i ≤ k) is set to 1 and other elements
# zeros" (*ibid.)*
#
# - **output layer:** number of nodes is equal to number of classes. However, instead of softmax function used in nominal classification, the authors used sigmoid function for each node so that it doesn't include the outputs from other nodes. Each output node calculates the probability of a data point belonging to class k independently.
#
# Because of the specific target encoding I can't use categorical or binary accuracy from keras metrics. I also can't use predict_classes method as it isn't suited for a situation where the probability in more than one output node is above the threshold (eg. >0.5). In order to calculate the true accuracy I have to bring the prediction probabilities vector for every data point back to the categorical encoding and compare the classes with y_val in the same encoding format. So I created **custom keras metric "ordinal_accuracy".**

# %%
# encoding y so that the net learn the orderings
# function takes binned y variable as input

def make_ordinal_encoding(y):
  ordinal= np.zeros((y.shape[0], 3), dtype=int)
  ordinal[np.arange(y.shape[0]), y] = 1
  ordinal[ordinal[:, 1] == 1, 0] = 1
  ordinal[ordinal[:, 2] == 1, 0] = 1
  ordinal[ordinal[:, 2] == 1, 1] = 1
  return ordinal

# %%
y_train_ord = make_ordinal_encoding(y_train)
y_val_ord = make_ordinal_encoding(y_val)
y_test_ord = make_ordinal_encoding(y_test)

# %%
# defining custom keras metric to calculate ordinal_accuracy

def ordinal_accuracy(y_true, y_pred):
  y_pred_labels = K.round(y_pred)   # bringing probability output to ordinal encoding form
  y_pred_class = K.sum(y_pred_labels, axis=-1)  # getting categorical class (actually class+1)
  y_true_class = K.sum(y_true, axis=-1)         
  return K.cast(K.equal(y_true_class, y_pred_class), K.floatx())

# %%
def build_lstm_model_2(list_of_layers):
  
  model = Sequential()
  model.add(Embedding(emb_matrix.shape[0],
                      emb_matrix.shape[1], 
                      input_length=max_len,
                      weights = [emb_matrix], 
                      trainable = False))
  for layer in list_of_layers:
    model.add(layer)
  model.summary() 
  
  model.compile(loss="mean_squared_error",
               optimizer="adam", 
               metrics=[ordinal_accuracy])
  return model

# %%
models = {        
          "ord_LSTM_300neurons":      [LSTM(300),
                                  Dense(3, activation="sigmoid")],
    
          "ord_LSTM_500neurons":      [LSTM(500),
                                  Dense(3, activation="sigmoid")],
    
          "ord_LSTM_1000neurons":      [LSTM(1000),
                                  Dense(3, activation="sigmoid")],        
          
          "ord_BiLSTM_Dense":          [Bidirectional(LSTM(300)),
                                  Dense(3, activation="sigmoid")],
          
          "ord_MultipleLSTM_Dense":    [LSTM(200, return_sequences=True),
                                  LSTM(100),
                                  Dense(3, activation="sigmoid")],
          
          "ord_LSTM_MultipleDense":     [LSTM(300),
                                  Dense(30, activation="relu"),
                                  Dense(3, activation="sigmoid")],
     
         
          "ord_Conv_Pool_LSTM_Dense": [Conv1D(32,3),
                                   MaxPooling1D(pool_size=2),
                                   LSTM(100),
                                   Dense(3, activation="sigmoid")]
}

# %%
lst = []
for model, params in models.items():
  acc = (evaluate_lstm_model(build_lstm_model_2(params), X_train_nn, X_val_nn, y_train_ord, y_val_ord, model))
  lst.append(acc)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 300)               721200
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 903
# =================================================================
# Total params: 10,479,303
# Trainable params: 722,103
# Non-trainable params: 9,757,200
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 162s 2ms/step - loss: 0.0569 - ordinal_accuracy: 0.7655 - val_loss: 0.0483 - val_ordinal_accuracy: 0.7998
# Epoch 2/100
# 69332/69332 [==============================] - 163s 2ms/step - loss: 0.0464 - ordinal_accuracy: 0.8075 - val_loss: 0.0467 - val_ordinal_accuracy: 0.8052
# Epoch 3/100
# 69332/69332 [==============================] - 162s 2ms/step - loss: 0.0434 - ordinal_accuracy: 0.8199 - val_loss: 0.0449 - val_ordinal_accuracy: 0.8114
# Epoch 4/100
# 69332/69332 [==============================] - 164s 2ms/step - loss: 0.0410 - ordinal_accuracy: 0.8307 - val_loss: 0.0441 - val_ordinal_accuracy: 0.8145
# Epoch 5/100
# 69332/69332 [==============================] - 164s 2ms/step - loss: 0.0381 - ordinal_accuracy: 0.8455 - val_loss: 0.0444 - val_ordinal_accuracy: 0.8121
# Epoch 6/100
# 69332/69332 [==============================] - 163s 2ms/step - loss: 0.0348 - ordinal_accuracy: 0.8603 - val_loss: 0.0452 - val_ordinal_accuracy: 0.8110
# Epoch 7/100
# 69332/69332 [==============================] - 161s 2ms/step - loss: 0.0309 - ordinal_accuracy: 0.8807 - val_loss: 0.0451 - val_ordinal_accuracy: 0.8155
# 15295/15295 [==============================] - 55s 4ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 500)               1602000
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 1503
# =================================================================
# Total params: 11,360,703
# Trainable params: 1,603,503
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 206s 3ms/step - loss: 0.0566 - ordinal_accuracy: 0.7660 - val_loss: 0.0494 - val_ordinal_accuracy: 0.7944
# Epoch 2/100
# 69332/69332 [==============================] - 204s 3ms/step - loss: 0.0462 - ordinal_accuracy: 0.8080 - val_loss: 0.0457 - val_ordinal_accuracy: 0.8068
# Epoch 3/100
# 69332/69332 [==============================] - 205s 3ms/step - loss: 0.0430 - ordinal_accuracy: 0.8220 - val_loss: 0.0463 - val_ordinal_accuracy: 0.8048
# Epoch 4/100
# 69332/69332 [==============================] - 206s 3ms/step - loss: 0.0404 - ordinal_accuracy: 0.8341 - val_loss: 0.0446 - val_ordinal_accuracy: 0.8137
# Epoch 5/100
# 69332/69332 [==============================] - 206s 3ms/step - loss: 0.0370 - ordinal_accuracy: 0.8502 - val_loss: 0.0441 - val_ordinal_accuracy: 0.8140
# Epoch 6/100
# 69332/69332 [==============================] - 205s 3ms/step - loss: 0.0330 - ordinal_accuracy: 0.8690 - val_loss: 0.0468 - val_ordinal_accuracy: 0.8062
# Epoch 7/100
# 69332/69332 [==============================] - 206s 3ms/step - loss: 0.0275 - ordinal_accuracy: 0.8937 - val_loss: 0.0504 - val_ordinal_accuracy: 0.7956
# Epoch 8/100
# 69332/69332 [==============================] - 205s 3ms/step - loss: 0.0215 - ordinal_accuracy: 0.9212 - val_loss: 0.0501 - val_ordinal_accuracy: 0.8036
# 15295/15295 [==============================] - 57s 4ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 1000)              5204000
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 3003
# =================================================================
# Total params: 14,964,203
# Trainable params: 5,207,003
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 401s 6ms/step - loss: 0.0592 - ordinal_accuracy: 0.7580 - val_loss: 0.0485 - val_ordinal_accuracy: 0.7973
# Epoch 2/100
# 69332/69332 [==============================] - 399s 6ms/step - loss: 0.0466 - ordinal_accuracy: 0.8058 - val_loss: 0.0470 - val_ordinal_accuracy: 0.8012
# Epoch 3/100
# 69332/69332 [==============================] - 401s 6ms/step - loss: 0.0433 - ordinal_accuracy: 0.8206 - val_loss: 0.0445 - val_ordinal_accuracy: 0.8146
# Epoch 4/100
# 69332/69332 [==============================] - 400s 6ms/step - loss: 0.0400 - ordinal_accuracy: 0.8353 - val_loss: 0.0438 - val_ordinal_accuracy: 0.8171
# Epoch 5/100
# 69332/69332 [==============================] - 400s 6ms/step - loss: 0.0404 - ordinal_accuracy: 0.8340 - val_loss: 0.0456 - val_ordinal_accuracy: 0.8138
# Epoch 6/100
# 69332/69332 [==============================] - 401s 6ms/step - loss: 0.0362 - ordinal_accuracy: 0.8538 - val_loss: 0.0446 - val_ordinal_accuracy: 0.8179
# Epoch 7/100
# 69332/69332 [==============================] - 401s 6ms/step - loss: 0.0304 - ordinal_accuracy: 0.8816 - val_loss: 0.0463 - val_ordinal_accuracy: 0.8111
# 15295/15295 [==============================] - 84s 6ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 600)               1442400
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 1803
# =================================================================
# Total params: 11,201,403
# Trainable params: 1,444,203
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 370s 5ms/step - loss: 0.0584 - ordinal_accuracy: 0.7597 - val_loss: 0.0482 - val_ordinal_accuracy: 0.7973
# Epoch 2/100
# 69332/69332 [==============================] - 369s 5ms/step - loss: 0.0467 - ordinal_accuracy: 0.8052 - val_loss: 0.0460 - val_ordinal_accuracy: 0.8053
# Epoch 3/100
# 69332/69332 [==============================] - 364s 5ms/step - loss: 0.0434 - ordinal_accuracy: 0.8197 - val_loss: 0.0456 - val_ordinal_accuracy: 0.8085
# Epoch 4/100
# 69332/69332 [==============================] - 366s 5ms/step - loss: 0.0408 - ordinal_accuracy: 0.8317 - val_loss: 0.0444 - val_ordinal_accuracy: 0.8129
# Epoch 5/100
# 69332/69332 [==============================] - 358s 5ms/step - loss: 0.0382 - ordinal_accuracy: 0.8451 - val_loss: 0.0443 - val_ordinal_accuracy: 0.8156
# Epoch 6/100
# 69332/69332 [==============================] - 359s 5ms/step - loss: 0.0351 - ordinal_accuracy: 0.8597 - val_loss: 0.0464 - val_ordinal_accuracy: 0.8078
# Epoch 7/100
# 69332/69332 [==============================] - 357s 5ms/step - loss: 0.0313 - ordinal_accuracy: 0.8772 - val_loss: 0.0473 - val_ordinal_accuracy: 0.8085
# Epoch 8/100
# 69332/69332 [==============================] - 359s 5ms/step - loss: 0.0271 - ordinal_accuracy: 0.8963 - val_loss: 0.0475 - val_ordinal_accuracy: 0.8082
# 15295/15295 [==============================] - 105s 7ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 136, 200)          400800
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 100)               120400
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 10,278,703
# Trainable params: 521,503
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 308s 4ms/step - loss: 0.0577 - ordinal_accuracy: 0.7647 - val_loss: 0.0491 - val_ordinal_accuracy: 0.7934
# Epoch 2/100
# 69332/69332 [==============================] - 304s 4ms/step - loss: 0.0474 - ordinal_accuracy: 0.8030 - val_loss: 0.0463 - val_ordinal_accuracy: 0.8047
# Epoch 3/100
# 69332/69332 [==============================] - 304s 4ms/step - loss: 0.0440 - ordinal_accuracy: 0.8170 - val_loss: 0.0454 - val_ordinal_accuracy: 0.8071
# Epoch 4/100
# 69332/69332 [==============================] - 305s 4ms/step - loss: 0.0408 - ordinal_accuracy: 0.8308 - val_loss: 0.0448 - val_ordinal_accuracy: 0.8099
# Epoch 5/100
# 69332/69332 [==============================] - 307s 4ms/step - loss: 0.0383 - ordinal_accuracy: 0.8445 - val_loss: 0.0440 - val_ordinal_accuracy: 0.8170
# Epoch 6/100
# 69332/69332 [==============================] - 311s 4ms/step - loss: 0.0352 - ordinal_accuracy: 0.8586 - val_loss: 0.0450 - val_ordinal_accuracy: 0.8141
# Epoch 7/100
# 69332/69332 [==============================] - 309s 4ms/step - loss: 0.0321 - ordinal_accuracy: 0.8738 - val_loss: 0.0457 - val_ordinal_accuracy: 0.8135
# Epoch 8/100
# 69332/69332 [==============================] - 308s 4ms/step - loss: 0.0281 - ordinal_accuracy: 0.8917 - val_loss: 0.0488 - val_ordinal_accuracy: 0.8066
# 15295/15295 [==============================] - 105s 7ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 300)               721200
# _________________________________________________________________
# dense_6 (Dense)              (None, 30)                9030
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 93
# =================================================================
# Total params: 10,487,523
# Trainable params: 730,323
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 161s 2ms/step - loss: 0.0584 - ordinal_accuracy: 0.7624 - val_loss: 0.0499 - val_ordinal_accuracy: 0.7917
# Epoch 2/100
# 69332/69332 [==============================] - 160s 2ms/step - loss: 0.0470 - ordinal_accuracy: 0.8054 - val_loss: 0.0467 - val_ordinal_accuracy: 0.7998
# Epoch 3/100
# 69332/69332 [==============================] - 160s 2ms/step - loss: 0.0437 - ordinal_accuracy: 0.8189 - val_loss: 0.0451 - val_ordinal_accuracy: 0.8122
# Epoch 4/100
# 69332/69332 [==============================] - 159s 2ms/step - loss: 0.0408 - ordinal_accuracy: 0.8323 - val_loss: 0.0442 - val_ordinal_accuracy: 0.8160
# Epoch 5/100
# 69332/69332 [==============================] - 160s 2ms/step - loss: 0.0380 - ordinal_accuracy: 0.8459 - val_loss: 0.0439 - val_ordinal_accuracy: 0.8199
# Epoch 6/100
# 69332/69332 [==============================] - 160s 2ms/step - loss: 0.0351 - ordinal_accuracy: 0.8613 - val_loss: 0.0449 - val_ordinal_accuracy: 0.8187
# Epoch 7/100
# 69332/69332 [==============================] - 158s 2ms/step - loss: 0.0313 - ordinal_accuracy: 0.8775 - val_loss: 0.0462 - val_ordinal_accuracy: 0.8111
# Epoch 8/100
# 69332/69332 [==============================] - 157s 2ms/step - loss: 0.0267 - ordinal_accuracy: 0.8983 - val_loss: 0.0484 - val_ordinal_accuracy: 0.8112
# 15295/15295 [==============================] - 53s 3ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 134, 32)           28832
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 67, 32)            0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 100)               53200
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 9,839,535
# Trainable params: 82,335
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 92s 1ms/step - loss: 0.0580 - ordinal_accuracy: 0.7634 - val_loss: 0.0508 - val_ordinal_accuracy: 0.7876
# Epoch 2/100
# 69332/69332 [==============================] - 89s 1ms/step - loss: 0.0488 - ordinal_accuracy: 0.7967 - val_loss: 0.0489 - val_ordinal_accuracy: 0.7971
# Epoch 3/100
# 69332/69332 [==============================] - 89s 1ms/step - loss: 0.0463 - ordinal_accuracy: 0.8068 - val_loss: 0.0489 - val_ordinal_accuracy: 0.7926
# Epoch 4/100
# 69332/69332 [==============================] - 88s 1ms/step - loss: 0.0443 - ordinal_accuracy: 0.8176 - val_loss: 0.0484 - val_ordinal_accuracy: 0.7962
# Epoch 5/100
# 69332/69332 [==============================] - 89s 1ms/step - loss: 0.0424 - ordinal_accuracy: 0.8247 - val_loss: 0.0482 - val_ordinal_accuracy: 0.7965
# Epoch 6/100
# 69332/69332 [==============================] - 89s 1ms/step - loss: 0.0407 - ordinal_accuracy: 0.8358 - val_loss: 0.0470 - val_ordinal_accuracy: 0.8010
# Epoch 7/100
# 69332/69332 [==============================] - 89s 1ms/step - loss: 0.0392 - ordinal_accuracy: 0.8423 - val_loss: 0.0472 - val_ordinal_accuracy: 0.8030
# Epoch 8/100
# 69332/69332 [==============================] - 88s 1ms/step - loss: 0.0376 - ordinal_accuracy: 0.8492 - val_loss: 0.0489 - val_ordinal_accuracy: 0.7973
# Epoch 9/100
# 69332/69332 [==============================] - 89s 1ms/step - loss: 0.0359 - ordinal_accuracy: 0.8584 - val_loss: 0.0491 - val_ordinal_accuracy: 0.7999
# 15295/15295 [==============================] - 26s 2ms/step

# %%
lstm_2_results = pd.DataFrame(list(zip(models.keys(), lst)), columns=["model", "accuracy"]).sort_values(by="accuracy", ascending=False).reset_index(drop=True)

# %%
lstm_2_results
# Out:
#                       model  accuracy
# 0    ord_MultipleLSTM_Dense  0.820137
# 1    ord_LSTM_MultipleDense  0.819941
# 2       ord_LSTM_500neurons  0.819483
# 3      ord_LSTM_1000neurons  0.818830
# 4       ord_LSTM_300neurons  0.816476
# 5          ord_BiLSTM_Dense  0.816280
# 6  ord_Conv_Pool_LSTM_Dense  0.804904

# %% [markdown]
# ### Score on test set

# %% [markdown]
# The best model for ordinal classification is the neural net with two LSTM layers (200 and 100 neurons) and a Dense layer. Let's check how it scores on the test set.

# %%
# loading best model from a file and evaluating on test set

best_ord_clf = build_lstm_model_2(models["ord_MultipleLSTM_Dense"])
best_ord_clf.load_weights("data/best_nn_nom_ord.h5py")
best_ord_clf.compile(loss="mean_squared_error",
               optimizer="adam", 
               metrics=[ordinal_accuracy])
best_ord_acc = best_ord_clf.evaluate(X_test_nn, y_test_ord)[1]
print(f"Accuracy of the best model for ordinal classification: {best_ord_acc}")
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 136, 200)          400800
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 100)               120400
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 10,278,703
# Trainable params: 521,503
# Non-trainable params: 9,757,200
# _________________________________________________________________
# 17994/17994 [==============================] - 125s 7ms/step
# Accuracy of the best model for ordinal classification: 0.8179948871713671

# %% [markdown]
# ## Regression
#
# 3) Keeping target variable in its original form (points on scale 80-100).

# %%
y_train, y_test = train_test_split(y, test_size=0.15, 
                                                    random_state=42)
y_train, y_val = train_test_split(y_train, test_size=0.15, 
                                                          random_state=52)

# %% [markdown]
# ### Linear Regression and XGBoost

# %% [markdown]
# First I will search for the best parameters for Linear Regression and XGBoost. Both models will be learned on the dataset transformed so that it contains LDA features.

# %%
model_linear_reg = LinearRegression()
model_linear_reg.fit(X_train_lda, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
best_xgb = "best_xgbregressor.joblib"


model = XGBRegressor(scoring="mean_squared_error")

param_grid = {"n_estimators":ss.randint(100,300),
           "learning_rate":ss.uniform(0.01,0.3),
           "max_depth": ss.randint(5,30),
           "min_child_weight":ss.randint(1,50),
           "reg_lambda":ss.uniform(0.1,3)}
    
cv = RandomizedSearchCV(cv=5, 
                        estimator=model,
                        param_distributions=param_grid,
                        n_iter=30,
                        verbose=2)
cv.fit(X_train_lda, y_train)
    
joblib.dump(cv.best_estimator_, best_xgb)
    
print(mean_squared_error(y_val, cv.best_estimator_.predict(X_val_lda)),
         cv.best_params_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] learning_rate=0.12916891681627662, max_depth=21, min_child_weight=40, n_estimators=141, reg_lambda=1.3593064944587545
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  learning_rate=0.12916891681627662, max_depth=21, min_child_weight=40, n_estimators=141, reg_lambda=1.3593064944587545, total=  23.5s
# [CV] learning_rate=0.12916891681627662, max_depth=21, min_child_weight=40, n_estimators=141, reg_lambda=1.3593064944587545
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   26.1s remaining:    0.0s
# [CV]  learning_rate=0.12916891681627662, max_depth=21, min_child_weight=40, n_estimators=141, reg_lambda=1.3593064944587545, total=  23.6s
# [CV] learning_rate=0.12916891681627662, max_depth=21, min_child_weight=40, n_estimators=141, reg_lambda=1.3593064944587545
# [CV]  learning_rate=0.12916891681627662, max_depth=21, min_child_weight=40, n_estimators=141, reg_lambda=1.3593064944587545, total=  23.6s
# [CV] learning_rate=0.12916891681627662, max_depth=21, min_child_weight=40, n_estimators=141, reg_lambda=1.3593064944587545
# [CV]  learning_rate=0.12916891681627662, max_depth=21, min_child_weight=40, n_estimators=141, reg_lambda=1.3593064944587545, total=  23.5s
# [CV] learning_rate=0.12916891681627662, max_depth=21, min_child_weight=40, n_estimators=141, reg_lambda=1.3593064944587545
# [CV]  learning_rate=0.12916891681627662, max_depth=21, min_child_weight=40, n_estimators=141, reg_lambda=1.3593064944587545, total=  23.6s
# [CV] learning_rate=0.2567113003848573, max_depth=5, min_child_weight=32, n_estimators=296, reg_lambda=2.2454477149586536
# [CV]  learning_rate=0.2567113003848573, max_depth=5, min_child_weight=32, n_estimators=296, reg_lambda=2.2454477149586536, total=  13.2s
# [CV] learning_rate=0.2567113003848573, max_depth=5, min_child_weight=32, n_estimators=296, reg_lambda=2.2454477149586536
# [CV]  learning_rate=0.2567113003848573, max_depth=5, min_child_weight=32, n_estimators=296, reg_lambda=2.2454477149586536, total=  13.2s
# [CV] learning_rate=0.2567113003848573, max_depth=5, min_child_weight=32, n_estimators=296, reg_lambda=2.2454477149586536
# [CV]  learning_rate=0.2567113003848573, max_depth=5, min_child_weight=32, n_estimators=296, reg_lambda=2.2454477149586536, total=  13.2s
# [CV] learning_rate=0.2567113003848573, max_depth=5, min_child_weight=32, n_estimators=296, reg_lambda=2.2454477149586536
# [CV]  learning_rate=0.2567113003848573, max_depth=5, min_child_weight=32, n_estimators=296, reg_lambda=2.2454477149586536, total=  13.2s
# [CV] learning_rate=0.2567113003848573, max_depth=5, min_child_weight=32, n_estimators=296, reg_lambda=2.2454477149586536
# [CV]  learning_rate=0.2567113003848573, max_depth=5, min_child_weight=32, n_estimators=296, reg_lambda=2.2454477149586536, total=  13.3s
# [CV] learning_rate=0.2310731184001244, max_depth=25, min_child_weight=48, n_estimators=290, reg_lambda=1.7614113132638327
# [CV]  learning_rate=0.2310731184001244, max_depth=25, min_child_weight=48, n_estimators=290, reg_lambda=1.7614113132638327, total=  58.8s
# [CV] learning_rate=0.2310731184001244, max_depth=25, min_child_weight=48, n_estimators=290, reg_lambda=1.7614113132638327
# [CV]  learning_rate=0.2310731184001244, max_depth=25, min_child_weight=48, n_estimators=290, reg_lambda=1.7614113132638327, total=  59.1s
# [CV] learning_rate=0.2310731184001244, max_depth=25, min_child_weight=48, n_estimators=290, reg_lambda=1.7614113132638327
# [CV]  learning_rate=0.2310731184001244, max_depth=25, min_child_weight=48, n_estimators=290, reg_lambda=1.7614113132638327, total=  58.9s
# [CV] learning_rate=0.2310731184001244, max_depth=25, min_child_weight=48, n_estimators=290, reg_lambda=1.7614113132638327
# [CV]  learning_rate=0.2310731184001244, max_depth=25, min_child_weight=48, n_estimators=290, reg_lambda=1.7614113132638327, total=  59.0s
# [CV] learning_rate=0.2310731184001244, max_depth=25, min_child_weight=48, n_estimators=290, reg_lambda=1.7614113132638327
# [CV]  learning_rate=0.2310731184001244, max_depth=25, min_child_weight=48, n_estimators=290, reg_lambda=1.7614113132638327, total=  59.1s
# [CV] learning_rate=0.09268431857373183, max_depth=15, min_child_weight=35, n_estimators=125, reg_lambda=2.396002296289432
# [CV]  learning_rate=0.09268431857373183, max_depth=15, min_child_weight=35, n_estimators=125, reg_lambda=2.396002296289432, total=  14.8s
# [CV] learning_rate=0.09268431857373183, max_depth=15, min_child_weight=35, n_estimators=125, reg_lambda=2.396002296289432
# [CV]  learning_rate=0.09268431857373183, max_depth=15, min_child_weight=35, n_estimators=125, reg_lambda=2.396002296289432, total=  14.9s
# [CV] learning_rate=0.09268431857373183, max_depth=15, min_child_weight=35, n_estimators=125, reg_lambda=2.396002296289432
# [CV]  learning_rate=0.09268431857373183, max_depth=15, min_child_weight=35, n_estimators=125, reg_lambda=2.396002296289432, total=  14.5s
# [CV] learning_rate=0.09268431857373183, max_depth=15, min_child_weight=35, n_estimators=125, reg_lambda=2.396002296289432
# [CV]  learning_rate=0.09268431857373183, max_depth=15, min_child_weight=35, n_estimators=125, reg_lambda=2.396002296289432, total=  14.9s
# [CV] learning_rate=0.09268431857373183, max_depth=15, min_child_weight=35, n_estimators=125, reg_lambda=2.396002296289432
# [CV]  learning_rate=0.09268431857373183, max_depth=15, min_child_weight=35, n_estimators=125, reg_lambda=2.396002296289432, total=  14.9s
# [CV] learning_rate=0.17115914711266839, max_depth=12, min_child_weight=35, n_estimators=211, reg_lambda=2.091814193672706
# [CV]  learning_rate=0.17115914711266839, max_depth=12, min_child_weight=35, n_estimators=211, reg_lambda=2.091814193672706, total=  21.8s
# [CV] learning_rate=0.17115914711266839, max_depth=12, min_child_weight=35, n_estimators=211, reg_lambda=2.091814193672706
# [CV]  learning_rate=0.17115914711266839, max_depth=12, min_child_weight=35, n_estimators=211, reg_lambda=2.091814193672706, total=  21.6s
# [CV] learning_rate=0.17115914711266839, max_depth=12, min_child_weight=35, n_estimators=211, reg_lambda=2.091814193672706
# [CV]  learning_rate=0.17115914711266839, max_depth=12, min_child_weight=35, n_estimators=211, reg_lambda=2.091814193672706, total=  21.7s
# [CV] learning_rate=0.17115914711266839, max_depth=12, min_child_weight=35, n_estimators=211, reg_lambda=2.091814193672706
# [CV]  learning_rate=0.17115914711266839, max_depth=12, min_child_weight=35, n_estimators=211, reg_lambda=2.091814193672706, total=  21.7s
# [CV] learning_rate=0.17115914711266839, max_depth=12, min_child_weight=35, n_estimators=211, reg_lambda=2.091814193672706
# [CV]  learning_rate=0.17115914711266839, max_depth=12, min_child_weight=35, n_estimators=211, reg_lambda=2.091814193672706, total=  21.6s
# [CV] learning_rate=0.03654598108775055, max_depth=8, min_child_weight=24, n_estimators=261, reg_lambda=1.864609057593941
# [CV]  learning_rate=0.03654598108775055, max_depth=8, min_child_weight=24, n_estimators=261, reg_lambda=1.864609057593941, total=  18.4s
# [CV] learning_rate=0.03654598108775055, max_depth=8, min_child_weight=24, n_estimators=261, reg_lambda=1.864609057593941
# [CV]  learning_rate=0.03654598108775055, max_depth=8, min_child_weight=24, n_estimators=261, reg_lambda=1.864609057593941, total=  18.5s
# [CV] learning_rate=0.03654598108775055, max_depth=8, min_child_weight=24, n_estimators=261, reg_lambda=1.864609057593941
# [CV]  learning_rate=0.03654598108775055, max_depth=8, min_child_weight=24, n_estimators=261, reg_lambda=1.864609057593941, total=  18.3s
# [CV] learning_rate=0.03654598108775055, max_depth=8, min_child_weight=24, n_estimators=261, reg_lambda=1.864609057593941
# [CV]  learning_rate=0.03654598108775055, max_depth=8, min_child_weight=24, n_estimators=261, reg_lambda=1.864609057593941, total=  18.3s
# [CV] learning_rate=0.03654598108775055, max_depth=8, min_child_weight=24, n_estimators=261, reg_lambda=1.864609057593941
# [CV]  learning_rate=0.03654598108775055, max_depth=8, min_child_weight=24, n_estimators=261, reg_lambda=1.864609057593941, total=  18.4s
# [CV] learning_rate=0.20240283029728298, max_depth=8, min_child_weight=29, n_estimators=114, reg_lambda=1.7313975217990136
# [CV]  learning_rate=0.20240283029728298, max_depth=8, min_child_weight=29, n_estimators=114, reg_lambda=1.7313975217990136, total=   7.9s
# [CV] learning_rate=0.20240283029728298, max_depth=8, min_child_weight=29, n_estimators=114, reg_lambda=1.7313975217990136
# [CV]  learning_rate=0.20240283029728298, max_depth=8, min_child_weight=29, n_estimators=114, reg_lambda=1.7313975217990136, total=   8.1s
# [CV] learning_rate=0.20240283029728298, max_depth=8, min_child_weight=29, n_estimators=114, reg_lambda=1.7313975217990136
# [CV]  learning_rate=0.20240283029728298, max_depth=8, min_child_weight=29, n_estimators=114, reg_lambda=1.7313975217990136, total=   8.1s
# [CV] learning_rate=0.20240283029728298, max_depth=8, min_child_weight=29, n_estimators=114, reg_lambda=1.7313975217990136
# [CV]  learning_rate=0.20240283029728298, max_depth=8, min_child_weight=29, n_estimators=114, reg_lambda=1.7313975217990136, total=   8.1s
# [CV] learning_rate=0.20240283029728298, max_depth=8, min_child_weight=29, n_estimators=114, reg_lambda=1.7313975217990136
# [CV]  learning_rate=0.20240283029728298, max_depth=8, min_child_weight=29, n_estimators=114, reg_lambda=1.7313975217990136, total=   8.1s
# [CV] learning_rate=0.12469476873592482, max_depth=16, min_child_weight=12, n_estimators=107, reg_lambda=0.6302302316732477
# [CV]  learning_rate=0.12469476873592482, max_depth=16, min_child_weight=12, n_estimators=107, reg_lambda=0.6302302316732477, total=  14.3s
# [CV] learning_rate=0.12469476873592482, max_depth=16, min_child_weight=12, n_estimators=107, reg_lambda=0.6302302316732477
# [CV]  learning_rate=0.12469476873592482, max_depth=16, min_child_weight=12, n_estimators=107, reg_lambda=0.6302302316732477, total=  14.7s
# [CV] learning_rate=0.12469476873592482, max_depth=16, min_child_weight=12, n_estimators=107, reg_lambda=0.6302302316732477
# [CV]  learning_rate=0.12469476873592482, max_depth=16, min_child_weight=12, n_estimators=107, reg_lambda=0.6302302316732477, total=  14.6s
# [CV] learning_rate=0.12469476873592482, max_depth=16, min_child_weight=12, n_estimators=107, reg_lambda=0.6302302316732477
# [CV]  learning_rate=0.12469476873592482, max_depth=16, min_child_weight=12, n_estimators=107, reg_lambda=0.6302302316732477, total=  14.5s
# [CV] learning_rate=0.12469476873592482, max_depth=16, min_child_weight=12, n_estimators=107, reg_lambda=0.6302302316732477
# [CV]  learning_rate=0.12469476873592482, max_depth=16, min_child_weight=12, n_estimators=107, reg_lambda=0.6302302316732477, total=  14.6s
# [CV] learning_rate=0.05725505422795845, max_depth=18, min_child_weight=46, n_estimators=110, reg_lambda=0.6779848078313618
# [CV]  learning_rate=0.05725505422795845, max_depth=18, min_child_weight=46, n_estimators=110, reg_lambda=0.6779848078313618, total=  15.1s
# [CV] learning_rate=0.05725505422795845, max_depth=18, min_child_weight=46, n_estimators=110, reg_lambda=0.6779848078313618
# [CV]  learning_rate=0.05725505422795845, max_depth=18, min_child_weight=46, n_estimators=110, reg_lambda=0.6779848078313618, total=  15.2s
# [CV] learning_rate=0.05725505422795845, max_depth=18, min_child_weight=46, n_estimators=110, reg_lambda=0.6779848078313618
# [CV]  learning_rate=0.05725505422795845, max_depth=18, min_child_weight=46, n_estimators=110, reg_lambda=0.6779848078313618, total=  15.1s
# [CV] learning_rate=0.05725505422795845, max_depth=18, min_child_weight=46, n_estimators=110, reg_lambda=0.6779848078313618
# [CV]  learning_rate=0.05725505422795845, max_depth=18, min_child_weight=46, n_estimators=110, reg_lambda=0.6779848078313618, total=  15.1s
# [CV] learning_rate=0.05725505422795845, max_depth=18, min_child_weight=46, n_estimators=110, reg_lambda=0.6779848078313618
# [CV]  learning_rate=0.05725505422795845, max_depth=18, min_child_weight=46, n_estimators=110, reg_lambda=0.6779848078313618, total=  15.1s
# [CV] learning_rate=0.12059391023117676, max_depth=9, min_child_weight=30, n_estimators=285, reg_lambda=2.144194251546667
# [CV]  learning_rate=0.12059391023117676, max_depth=9, min_child_weight=30, n_estimators=285, reg_lambda=2.144194251546667, total=  22.3s
# [CV] learning_rate=0.12059391023117676, max_depth=9, min_child_weight=30, n_estimators=285, reg_lambda=2.144194251546667
# [CV]  learning_rate=0.12059391023117676, max_depth=9, min_child_weight=30, n_estimators=285, reg_lambda=2.144194251546667, total=  22.3s
# [CV] learning_rate=0.12059391023117676, max_depth=9, min_child_weight=30, n_estimators=285, reg_lambda=2.144194251546667
# [CV]  learning_rate=0.12059391023117676, max_depth=9, min_child_weight=30, n_estimators=285, reg_lambda=2.144194251546667, total=  22.3s
# [CV] learning_rate=0.12059391023117676, max_depth=9, min_child_weight=30, n_estimators=285, reg_lambda=2.144194251546667
# [CV]  learning_rate=0.12059391023117676, max_depth=9, min_child_weight=30, n_estimators=285, reg_lambda=2.144194251546667, total=  22.4s
# [CV] learning_rate=0.12059391023117676, max_depth=9, min_child_weight=30, n_estimators=285, reg_lambda=2.144194251546667
# [CV]  learning_rate=0.12059391023117676, max_depth=9, min_child_weight=30, n_estimators=285, reg_lambda=2.144194251546667, total=  22.5s
# [CV] learning_rate=0.19895761493537528, max_depth=20, min_child_weight=43, n_estimators=116, reg_lambda=1.9312488093950213
# [CV]  learning_rate=0.19895761493537528, max_depth=20, min_child_weight=43, n_estimators=116, reg_lambda=1.9312488093950213, total=  18.8s
# [CV] learning_rate=0.19895761493537528, max_depth=20, min_child_weight=43, n_estimators=116, reg_lambda=1.9312488093950213
# [CV]  learning_rate=0.19895761493537528, max_depth=20, min_child_weight=43, n_estimators=116, reg_lambda=1.9312488093950213, total=  18.3s
# [CV] learning_rate=0.19895761493537528, max_depth=20, min_child_weight=43, n_estimators=116, reg_lambda=1.9312488093950213
# [CV]  learning_rate=0.19895761493537528, max_depth=20, min_child_weight=43, n_estimators=116, reg_lambda=1.9312488093950213, total=  18.5s
# [CV] learning_rate=0.19895761493537528, max_depth=20, min_child_weight=43, n_estimators=116, reg_lambda=1.9312488093950213
# [CV]  learning_rate=0.19895761493537528, max_depth=20, min_child_weight=43, n_estimators=116, reg_lambda=1.9312488093950213, total=  18.9s
# [CV] learning_rate=0.19895761493537528, max_depth=20, min_child_weight=43, n_estimators=116, reg_lambda=1.9312488093950213
# [CV]  learning_rate=0.19895761493537528, max_depth=20, min_child_weight=43, n_estimators=116, reg_lambda=1.9312488093950213, total=  18.9s
# [CV] learning_rate=0.22852613435917715, max_depth=22, min_child_weight=42, n_estimators=137, reg_lambda=0.5699142410207422
# [CV]  learning_rate=0.22852613435917715, max_depth=22, min_child_weight=42, n_estimators=137, reg_lambda=0.5699142410207422, total=  24.8s
# [CV] learning_rate=0.22852613435917715, max_depth=22, min_child_weight=42, n_estimators=137, reg_lambda=0.5699142410207422
# [CV]  learning_rate=0.22852613435917715, max_depth=22, min_child_weight=42, n_estimators=137, reg_lambda=0.5699142410207422, total=  24.7s
# [CV] learning_rate=0.22852613435917715, max_depth=22, min_child_weight=42, n_estimators=137, reg_lambda=0.5699142410207422
# [CV]  learning_rate=0.22852613435917715, max_depth=22, min_child_weight=42, n_estimators=137, reg_lambda=0.5699142410207422, total=  24.6s
# [CV] learning_rate=0.22852613435917715, max_depth=22, min_child_weight=42, n_estimators=137, reg_lambda=0.5699142410207422
# [CV]  learning_rate=0.22852613435917715, max_depth=22, min_child_weight=42, n_estimators=137, reg_lambda=0.5699142410207422, total=  24.4s
# [CV] learning_rate=0.22852613435917715, max_depth=22, min_child_weight=42, n_estimators=137, reg_lambda=0.5699142410207422
# [CV]  learning_rate=0.22852613435917715, max_depth=22, min_child_weight=42, n_estimators=137, reg_lambda=0.5699142410207422, total=  24.5s
# [CV] learning_rate=0.023967184516176146, max_depth=13, min_child_weight=37, n_estimators=269, reg_lambda=0.5870468157618595
# [CV]  learning_rate=0.023967184516176146, max_depth=13, min_child_weight=37, n_estimators=269, reg_lambda=0.5870468157618595, total=  29.1s
# [CV] learning_rate=0.023967184516176146, max_depth=13, min_child_weight=37, n_estimators=269, reg_lambda=0.5870468157618595
# [CV]  learning_rate=0.023967184516176146, max_depth=13, min_child_weight=37, n_estimators=269, reg_lambda=0.5870468157618595, total=  28.8s
# [CV] learning_rate=0.023967184516176146, max_depth=13, min_child_weight=37, n_estimators=269, reg_lambda=0.5870468157618595
# [CV]  learning_rate=0.023967184516176146, max_depth=13, min_child_weight=37, n_estimators=269, reg_lambda=0.5870468157618595, total=  29.0s
# [CV] learning_rate=0.023967184516176146, max_depth=13, min_child_weight=37, n_estimators=269, reg_lambda=0.5870468157618595
# [CV]  learning_rate=0.023967184516176146, max_depth=13, min_child_weight=37, n_estimators=269, reg_lambda=0.5870468157618595, total=  28.8s
# [CV] learning_rate=0.023967184516176146, max_depth=13, min_child_weight=37, n_estimators=269, reg_lambda=0.5870468157618595
# [CV]  learning_rate=0.023967184516176146, max_depth=13, min_child_weight=37, n_estimators=269, reg_lambda=0.5870468157618595, total=  28.8s
# [CV] learning_rate=0.11301147552719897, max_depth=25, min_child_weight=12, n_estimators=101, reg_lambda=1.9250669310814117
# [CV]  learning_rate=0.11301147552719897, max_depth=25, min_child_weight=12, n_estimators=101, reg_lambda=1.9250669310814117, total=  19.4s
# [CV] learning_rate=0.11301147552719897, max_depth=25, min_child_weight=12, n_estimators=101, reg_lambda=1.9250669310814117
# [CV]  learning_rate=0.11301147552719897, max_depth=25, min_child_weight=12, n_estimators=101, reg_lambda=1.9250669310814117, total=  19.4s
# [CV] learning_rate=0.11301147552719897, max_depth=25, min_child_weight=12, n_estimators=101, reg_lambda=1.9250669310814117
# [CV]  learning_rate=0.11301147552719897, max_depth=25, min_child_weight=12, n_estimators=101, reg_lambda=1.9250669310814117, total=  19.3s
# [CV] learning_rate=0.11301147552719897, max_depth=25, min_child_weight=12, n_estimators=101, reg_lambda=1.9250669310814117
# [CV]  learning_rate=0.11301147552719897, max_depth=25, min_child_weight=12, n_estimators=101, reg_lambda=1.9250669310814117, total=  19.4s
# [CV] learning_rate=0.11301147552719897, max_depth=25, min_child_weight=12, n_estimators=101, reg_lambda=1.9250669310814117
# [CV]  learning_rate=0.11301147552719897, max_depth=25, min_child_weight=12, n_estimators=101, reg_lambda=1.9250669310814117, total=  19.3s
# [CV] learning_rate=0.03756582546677776, max_depth=6, min_child_weight=42, n_estimators=178, reg_lambda=0.20089906877155686
# [CV]  learning_rate=0.03756582546677776, max_depth=6, min_child_weight=42, n_estimators=178, reg_lambda=0.20089906877155686, total=  10.0s
# [CV] learning_rate=0.03756582546677776, max_depth=6, min_child_weight=42, n_estimators=178, reg_lambda=0.20089906877155686
# [CV]  learning_rate=0.03756582546677776, max_depth=6, min_child_weight=42, n_estimators=178, reg_lambda=0.20089906877155686, total=  10.1s
# [CV] learning_rate=0.03756582546677776, max_depth=6, min_child_weight=42, n_estimators=178, reg_lambda=0.20089906877155686
# [CV]  learning_rate=0.03756582546677776, max_depth=6, min_child_weight=42, n_estimators=178, reg_lambda=0.20089906877155686, total=  10.1s
# [CV] learning_rate=0.03756582546677776, max_depth=6, min_child_weight=42, n_estimators=178, reg_lambda=0.20089906877155686
# [CV]  learning_rate=0.03756582546677776, max_depth=6, min_child_weight=42, n_estimators=178, reg_lambda=0.20089906877155686, total=  10.0s
# [CV] learning_rate=0.03756582546677776, max_depth=6, min_child_weight=42, n_estimators=178, reg_lambda=0.20089906877155686
# [CV]  learning_rate=0.03756582546677776, max_depth=6, min_child_weight=42, n_estimators=178, reg_lambda=0.20089906877155686, total=  10.1s
# [CV] learning_rate=0.03973773992606299, max_depth=21, min_child_weight=27, n_estimators=165, reg_lambda=0.37382677018802146
# [CV]  learning_rate=0.03973773992606299, max_depth=21, min_child_weight=27, n_estimators=165, reg_lambda=0.37382677018802146, total=  27.0s
# [CV] learning_rate=0.03973773992606299, max_depth=21, min_child_weight=27, n_estimators=165, reg_lambda=0.37382677018802146
# [CV]  learning_rate=0.03973773992606299, max_depth=21, min_child_weight=27, n_estimators=165, reg_lambda=0.37382677018802146, total=  26.7s
# [CV] learning_rate=0.03973773992606299, max_depth=21, min_child_weight=27, n_estimators=165, reg_lambda=0.37382677018802146
# [CV]  learning_rate=0.03973773992606299, max_depth=21, min_child_weight=27, n_estimators=165, reg_lambda=0.37382677018802146, total=  27.0s
# [CV] learning_rate=0.03973773992606299, max_depth=21, min_child_weight=27, n_estimators=165, reg_lambda=0.37382677018802146
# [CV]  learning_rate=0.03973773992606299, max_depth=21, min_child_weight=27, n_estimators=165, reg_lambda=0.37382677018802146, total=  26.8s
# [CV] learning_rate=0.03973773992606299, max_depth=21, min_child_weight=27, n_estimators=165, reg_lambda=0.37382677018802146
# [CV]  learning_rate=0.03973773992606299, max_depth=21, min_child_weight=27, n_estimators=165, reg_lambda=0.37382677018802146, total=  27.0s
# [CV] learning_rate=0.12254609082430504, max_depth=11, min_child_weight=5, n_estimators=266, reg_lambda=1.3566722197240688
# [CV]  learning_rate=0.12254609082430504, max_depth=11, min_child_weight=5, n_estimators=266, reg_lambda=1.3566722197240688, total=  25.6s
# [CV] learning_rate=0.12254609082430504, max_depth=11, min_child_weight=5, n_estimators=266, reg_lambda=1.3566722197240688
# [CV]  learning_rate=0.12254609082430504, max_depth=11, min_child_weight=5, n_estimators=266, reg_lambda=1.3566722197240688, total=  25.7s
# [CV] learning_rate=0.12254609082430504, max_depth=11, min_child_weight=5, n_estimators=266, reg_lambda=1.3566722197240688
# [CV]  learning_rate=0.12254609082430504, max_depth=11, min_child_weight=5, n_estimators=266, reg_lambda=1.3566722197240688, total=  25.5s
# [CV] learning_rate=0.12254609082430504, max_depth=11, min_child_weight=5, n_estimators=266, reg_lambda=1.3566722197240688
# [CV]  learning_rate=0.12254609082430504, max_depth=11, min_child_weight=5, n_estimators=266, reg_lambda=1.3566722197240688, total=  25.6s
# [CV] learning_rate=0.12254609082430504, max_depth=11, min_child_weight=5, n_estimators=266, reg_lambda=1.3566722197240688
# [CV]  learning_rate=0.12254609082430504, max_depth=11, min_child_weight=5, n_estimators=266, reg_lambda=1.3566722197240688, total=  25.7s
# [CV] learning_rate=0.048971164128952444, max_depth=24, min_child_weight=21, n_estimators=177, reg_lambda=0.6198747623762085
# [CV]  learning_rate=0.048971164128952444, max_depth=24, min_child_weight=21, n_estimators=177, reg_lambda=0.6198747623762085, total=  32.4s
# [CV] learning_rate=0.048971164128952444, max_depth=24, min_child_weight=21, n_estimators=177, reg_lambda=0.6198747623762085
# [CV]  learning_rate=0.048971164128952444, max_depth=24, min_child_weight=21, n_estimators=177, reg_lambda=0.6198747623762085, total=  32.4s
# [CV] learning_rate=0.048971164128952444, max_depth=24, min_child_weight=21, n_estimators=177, reg_lambda=0.6198747623762085
# [CV]  learning_rate=0.048971164128952444, max_depth=24, min_child_weight=21, n_estimators=177, reg_lambda=0.6198747623762085, total=  32.4s
# [CV] learning_rate=0.048971164128952444, max_depth=24, min_child_weight=21, n_estimators=177, reg_lambda=0.6198747623762085
# [CV]  learning_rate=0.048971164128952444, max_depth=24, min_child_weight=21, n_estimators=177, reg_lambda=0.6198747623762085, total=  32.3s
# [CV] learning_rate=0.048971164128952444, max_depth=24, min_child_weight=21, n_estimators=177, reg_lambda=0.6198747623762085
# [CV]  learning_rate=0.048971164128952444, max_depth=24, min_child_weight=21, n_estimators=177, reg_lambda=0.6198747623762085, total=  32.6s
# [CV] learning_rate=0.011838211198518658, max_depth=26, min_child_weight=10, n_estimators=267, reg_lambda=2.1492352193245514
# [CV]  learning_rate=0.011838211198518658, max_depth=26, min_child_weight=10, n_estimators=267, reg_lambda=2.1492352193245514, total=  22.4s
# [CV] learning_rate=0.011838211198518658, max_depth=26, min_child_weight=10, n_estimators=267, reg_lambda=2.1492352193245514
# [CV]  learning_rate=0.011838211198518658, max_depth=26, min_child_weight=10, n_estimators=267, reg_lambda=2.1492352193245514, total=  21.8s
# [CV] learning_rate=0.011838211198518658, max_depth=26, min_child_weight=10, n_estimators=267, reg_lambda=2.1492352193245514
# [CV]  learning_rate=0.011838211198518658, max_depth=26, min_child_weight=10, n_estimators=267, reg_lambda=2.1492352193245514, total=  22.0s
# [CV] learning_rate=0.011838211198518658, max_depth=26, min_child_weight=10, n_estimators=267, reg_lambda=2.1492352193245514
# [CV]  learning_rate=0.011838211198518658, max_depth=26, min_child_weight=10, n_estimators=267, reg_lambda=2.1492352193245514, total=  22.0s
# [CV] learning_rate=0.011838211198518658, max_depth=26, min_child_weight=10, n_estimators=267, reg_lambda=2.1492352193245514
# [CV]  learning_rate=0.011838211198518658, max_depth=26, min_child_weight=10, n_estimators=267, reg_lambda=2.1492352193245514, total=  22.3s
# [CV] learning_rate=0.03546801790751838, max_depth=24, min_child_weight=16, n_estimators=166, reg_lambda=1.13920272479641
# [CV]  learning_rate=0.03546801790751838, max_depth=24, min_child_weight=16, n_estimators=166, reg_lambda=1.13920272479641, total=  27.2s
# [CV] learning_rate=0.03546801790751838, max_depth=24, min_child_weight=16, n_estimators=166, reg_lambda=1.13920272479641
# [CV]  learning_rate=0.03546801790751838, max_depth=24, min_child_weight=16, n_estimators=166, reg_lambda=1.13920272479641, total=  27.1s
# [CV] learning_rate=0.03546801790751838, max_depth=24, min_child_weight=16, n_estimators=166, reg_lambda=1.13920272479641
# [CV]  learning_rate=0.03546801790751838, max_depth=24, min_child_weight=16, n_estimators=166, reg_lambda=1.13920272479641, total=  27.4s
# [CV] learning_rate=0.03546801790751838, max_depth=24, min_child_weight=16, n_estimators=166, reg_lambda=1.13920272479641
# [CV]  learning_rate=0.03546801790751838, max_depth=24, min_child_weight=16, n_estimators=166, reg_lambda=1.13920272479641, total=  27.0s
# [CV] learning_rate=0.03546801790751838, max_depth=24, min_child_weight=16, n_estimators=166, reg_lambda=1.13920272479641
# [CV]  learning_rate=0.03546801790751838, max_depth=24, min_child_weight=16, n_estimators=166, reg_lambda=1.13920272479641, total=  27.5s
# [CV] learning_rate=0.2501081568710648, max_depth=21, min_child_weight=14, n_estimators=225, reg_lambda=2.170941033926012
# [CV]  learning_rate=0.2501081568710648, max_depth=21, min_child_weight=14, n_estimators=225, reg_lambda=2.170941033926012, total=  40.4s
# [CV] learning_rate=0.2501081568710648, max_depth=21, min_child_weight=14, n_estimators=225, reg_lambda=2.170941033926012
# [CV]  learning_rate=0.2501081568710648, max_depth=21, min_child_weight=14, n_estimators=225, reg_lambda=2.170941033926012, total=  40.8s
# [CV] learning_rate=0.2501081568710648, max_depth=21, min_child_weight=14, n_estimators=225, reg_lambda=2.170941033926012
# [CV]  learning_rate=0.2501081568710648, max_depth=21, min_child_weight=14, n_estimators=225, reg_lambda=2.170941033926012, total=  39.7s
# [CV] learning_rate=0.2501081568710648, max_depth=21, min_child_weight=14, n_estimators=225, reg_lambda=2.170941033926012
# [CV]  learning_rate=0.2501081568710648, max_depth=21, min_child_weight=14, n_estimators=225, reg_lambda=2.170941033926012, total=  40.0s
# [CV] learning_rate=0.2501081568710648, max_depth=21, min_child_weight=14, n_estimators=225, reg_lambda=2.170941033926012
# [CV]  learning_rate=0.2501081568710648, max_depth=21, min_child_weight=14, n_estimators=225, reg_lambda=2.170941033926012, total=  39.8s
# [CV] learning_rate=0.06456525423478934, max_depth=14, min_child_weight=11, n_estimators=288, reg_lambda=1.8404198381809989
# [CV]  learning_rate=0.06456525423478934, max_depth=14, min_child_weight=11, n_estimators=288, reg_lambda=1.8404198381809989, total=  34.0s
# [CV] learning_rate=0.06456525423478934, max_depth=14, min_child_weight=11, n_estimators=288, reg_lambda=1.8404198381809989
# [CV]  learning_rate=0.06456525423478934, max_depth=14, min_child_weight=11, n_estimators=288, reg_lambda=1.8404198381809989, total=  36.4s
# [CV] learning_rate=0.06456525423478934, max_depth=14, min_child_weight=11, n_estimators=288, reg_lambda=1.8404198381809989
# [CV]  learning_rate=0.06456525423478934, max_depth=14, min_child_weight=11, n_estimators=288, reg_lambda=1.8404198381809989, total=  34.1s
# [CV] learning_rate=0.06456525423478934, max_depth=14, min_child_weight=11, n_estimators=288, reg_lambda=1.8404198381809989
# [CV]  learning_rate=0.06456525423478934, max_depth=14, min_child_weight=11, n_estimators=288, reg_lambda=1.8404198381809989, total=  34.1s
# [CV] learning_rate=0.06456525423478934, max_depth=14, min_child_weight=11, n_estimators=288, reg_lambda=1.8404198381809989
# [CV]  learning_rate=0.06456525423478934, max_depth=14, min_child_weight=11, n_estimators=288, reg_lambda=1.8404198381809989, total=  34.1s
# [CV] learning_rate=0.15615887447050944, max_depth=6, min_child_weight=8, n_estimators=242, reg_lambda=0.4382358319498213
# [CV]  learning_rate=0.15615887447050944, max_depth=6, min_child_weight=8, n_estimators=242, reg_lambda=0.4382358319498213, total=  13.1s
# [CV] learning_rate=0.15615887447050944, max_depth=6, min_child_weight=8, n_estimators=242, reg_lambda=0.4382358319498213
# [CV]  learning_rate=0.15615887447050944, max_depth=6, min_child_weight=8, n_estimators=242, reg_lambda=0.4382358319498213, total=  13.1s
# [CV] learning_rate=0.15615887447050944, max_depth=6, min_child_weight=8, n_estimators=242, reg_lambda=0.4382358319498213
# [CV]  learning_rate=0.15615887447050944, max_depth=6, min_child_weight=8, n_estimators=242, reg_lambda=0.4382358319498213, total=  13.1s
# [CV] learning_rate=0.15615887447050944, max_depth=6, min_child_weight=8, n_estimators=242, reg_lambda=0.4382358319498213
# [CV]  learning_rate=0.15615887447050944, max_depth=6, min_child_weight=8, n_estimators=242, reg_lambda=0.4382358319498213, total=  13.0s
# [CV] learning_rate=0.15615887447050944, max_depth=6, min_child_weight=8, n_estimators=242, reg_lambda=0.4382358319498213
# [CV]  learning_rate=0.15615887447050944, max_depth=6, min_child_weight=8, n_estimators=242, reg_lambda=0.4382358319498213, total=  13.0s
# [CV] learning_rate=0.05394021775591206, max_depth=22, min_child_weight=18, n_estimators=104, reg_lambda=0.49231317464001134
# [CV]  learning_rate=0.05394021775591206, max_depth=22, min_child_weight=18, n_estimators=104, reg_lambda=0.49231317464001134, total=  17.0s
# [CV] learning_rate=0.05394021775591206, max_depth=22, min_child_weight=18, n_estimators=104, reg_lambda=0.49231317464001134
# [CV]  learning_rate=0.05394021775591206, max_depth=22, min_child_weight=18, n_estimators=104, reg_lambda=0.49231317464001134, total=  17.0s
# [CV] learning_rate=0.05394021775591206, max_depth=22, min_child_weight=18, n_estimators=104, reg_lambda=0.49231317464001134
# [CV]  learning_rate=0.05394021775591206, max_depth=22, min_child_weight=18, n_estimators=104, reg_lambda=0.49231317464001134, total=  18.4s
# [CV] learning_rate=0.05394021775591206, max_depth=22, min_child_weight=18, n_estimators=104, reg_lambda=0.49231317464001134
# [CV]  learning_rate=0.05394021775591206, max_depth=22, min_child_weight=18, n_estimators=104, reg_lambda=0.49231317464001134, total=  17.3s
# [CV] learning_rate=0.05394021775591206, max_depth=22, min_child_weight=18, n_estimators=104, reg_lambda=0.49231317464001134
# [CV]  learning_rate=0.05394021775591206, max_depth=22, min_child_weight=18, n_estimators=104, reg_lambda=0.49231317464001134, total=  16.9s
# [CV] learning_rate=0.3067499828798976, max_depth=14, min_child_weight=40, n_estimators=199, reg_lambda=0.8027884478003233
# [CV]  learning_rate=0.3067499828798976, max_depth=14, min_child_weight=40, n_estimators=199, reg_lambda=0.8027884478003233, total=  23.4s
# [CV] learning_rate=0.3067499828798976, max_depth=14, min_child_weight=40, n_estimators=199, reg_lambda=0.8027884478003233
# [CV]  learning_rate=0.3067499828798976, max_depth=14, min_child_weight=40, n_estimators=199, reg_lambda=0.8027884478003233, total=  23.6s
# [CV] learning_rate=0.3067499828798976, max_depth=14, min_child_weight=40, n_estimators=199, reg_lambda=0.8027884478003233
# [CV]  learning_rate=0.3067499828798976, max_depth=14, min_child_weight=40, n_estimators=199, reg_lambda=0.8027884478003233, total=  23.5s
# [CV] learning_rate=0.3067499828798976, max_depth=14, min_child_weight=40, n_estimators=199, reg_lambda=0.8027884478003233
# [CV]  learning_rate=0.3067499828798976, max_depth=14, min_child_weight=40, n_estimators=199, reg_lambda=0.8027884478003233, total=  23.3s
# [CV] learning_rate=0.3067499828798976, max_depth=14, min_child_weight=40, n_estimators=199, reg_lambda=0.8027884478003233
# [CV]  learning_rate=0.3067499828798976, max_depth=14, min_child_weight=40, n_estimators=199, reg_lambda=0.8027884478003233, total=  23.5s
# [CV] learning_rate=0.30924822893666076, max_depth=12, min_child_weight=32, n_estimators=140, reg_lambda=1.64388572180951
# [CV]  learning_rate=0.30924822893666076, max_depth=12, min_child_weight=32, n_estimators=140, reg_lambda=1.64388572180951, total=  14.4s
# [CV] learning_rate=0.30924822893666076, max_depth=12, min_child_weight=32, n_estimators=140, reg_lambda=1.64388572180951
# [CV]  learning_rate=0.30924822893666076, max_depth=12, min_child_weight=32, n_estimators=140, reg_lambda=1.64388572180951, total=  14.4s
# [CV] learning_rate=0.30924822893666076, max_depth=12, min_child_weight=32, n_estimators=140, reg_lambda=1.64388572180951
# [CV]  learning_rate=0.30924822893666076, max_depth=12, min_child_weight=32, n_estimators=140, reg_lambda=1.64388572180951, total=  14.4s
# [CV] learning_rate=0.30924822893666076, max_depth=12, min_child_weight=32, n_estimators=140, reg_lambda=1.64388572180951
# [CV]  learning_rate=0.30924822893666076, max_depth=12, min_child_weight=32, n_estimators=140, reg_lambda=1.64388572180951, total=  15.9s
# [CV] learning_rate=0.30924822893666076, max_depth=12, min_child_weight=32, n_estimators=140, reg_lambda=1.64388572180951
# [CV]  learning_rate=0.30924822893666076, max_depth=12, min_child_weight=32, n_estimators=140, reg_lambda=1.64388572180951, total=  14.4s
# [CV] learning_rate=0.13253735906311517, max_depth=23, min_child_weight=44, n_estimators=273, reg_lambda=2.953690317373809
# [CV]  learning_rate=0.13253735906311517, max_depth=23, min_child_weight=44, n_estimators=273, reg_lambda=2.953690317373809, total=  50.5s
# [CV] learning_rate=0.13253735906311517, max_depth=23, min_child_weight=44, n_estimators=273, reg_lambda=2.953690317373809
# [CV]  learning_rate=0.13253735906311517, max_depth=23, min_child_weight=44, n_estimators=273, reg_lambda=2.953690317373809, total=  49.8s
# [CV] learning_rate=0.13253735906311517, max_depth=23, min_child_weight=44, n_estimators=273, reg_lambda=2.953690317373809
# [CV]  learning_rate=0.13253735906311517, max_depth=23, min_child_weight=44, n_estimators=273, reg_lambda=2.953690317373809, total=  49.8s
# [CV] learning_rate=0.13253735906311517, max_depth=23, min_child_weight=44, n_estimators=273, reg_lambda=2.953690317373809
# [CV]  learning_rate=0.13253735906311517, max_depth=23, min_child_weight=44, n_estimators=273, reg_lambda=2.953690317373809, total=  51.3s
# [CV] learning_rate=0.13253735906311517, max_depth=23, min_child_weight=44, n_estimators=273, reg_lambda=2.953690317373809
# [CV]  learning_rate=0.13253735906311517, max_depth=23, min_child_weight=44, n_estimators=273, reg_lambda=2.953690317373809, total=  49.4s
# [CV] learning_rate=0.13258280347634654, max_depth=21, min_child_weight=11, n_estimators=163, reg_lambda=0.5486636868478773
# [CV]  learning_rate=0.13258280347634654, max_depth=21, min_child_weight=11, n_estimators=163, reg_lambda=0.5486636868478773, total=  28.8s
# [CV] learning_rate=0.13258280347634654, max_depth=21, min_child_weight=11, n_estimators=163, reg_lambda=0.5486636868478773
# [CV]  learning_rate=0.13258280347634654, max_depth=21, min_child_weight=11, n_estimators=163, reg_lambda=0.5486636868478773, total=  28.7s
# [CV] learning_rate=0.13258280347634654, max_depth=21, min_child_weight=11, n_estimators=163, reg_lambda=0.5486636868478773
# [CV]  learning_rate=0.13258280347634654, max_depth=21, min_child_weight=11, n_estimators=163, reg_lambda=0.5486636868478773, total=  28.5s
# [CV] learning_rate=0.13258280347634654, max_depth=21, min_child_weight=11, n_estimators=163, reg_lambda=0.5486636868478773
# [CV]  learning_rate=0.13258280347634654, max_depth=21, min_child_weight=11, n_estimators=163, reg_lambda=0.5486636868478773, total=  28.7s
# [CV] learning_rate=0.13258280347634654, max_depth=21, min_child_weight=11, n_estimators=163, reg_lambda=0.5486636868478773
# [CV]  learning_rate=0.13258280347634654, max_depth=21, min_child_weight=11, n_estimators=163, reg_lambda=0.5486636868478773, total=  28.9s
# [CV] learning_rate=0.28868547438060826, max_depth=10, min_child_weight=35, n_estimators=216, reg_lambda=0.7002089671772392
# [CV]  learning_rate=0.28868547438060826, max_depth=10, min_child_weight=35, n_estimators=216, reg_lambda=0.7002089671772392, total=  18.5s
# [CV] learning_rate=0.28868547438060826, max_depth=10, min_child_weight=35, n_estimators=216, reg_lambda=0.7002089671772392
# [CV]  learning_rate=0.28868547438060826, max_depth=10, min_child_weight=35, n_estimators=216, reg_lambda=0.7002089671772392, total=  18.4s
# [CV] learning_rate=0.28868547438060826, max_depth=10, min_child_weight=35, n_estimators=216, reg_lambda=0.7002089671772392
# [CV]  learning_rate=0.28868547438060826, max_depth=10, min_child_weight=35, n_estimators=216, reg_lambda=0.7002089671772392, total=  18.5s
# [CV] learning_rate=0.28868547438060826, max_depth=10, min_child_weight=35, n_estimators=216, reg_lambda=0.7002089671772392
# [CV]  learning_rate=0.28868547438060826, max_depth=10, min_child_weight=35, n_estimators=216, reg_lambda=0.7002089671772392, total=  18.4s
# [CV] learning_rate=0.28868547438060826, max_depth=10, min_child_weight=35, n_estimators=216, reg_lambda=0.7002089671772392
# [CV]  learning_rate=0.28868547438060826, max_depth=10, min_child_weight=35, n_estimators=216, reg_lambda=0.7002089671772392, total=  18.4s
# [CV] learning_rate=0.11124727400636987, max_depth=14, min_child_weight=34, n_estimators=118, reg_lambda=0.452459860467873
# [CV]  learning_rate=0.11124727400636987, max_depth=14, min_child_weight=34, n_estimators=118, reg_lambda=0.452459860467873, total=  13.9s
# [CV] learning_rate=0.11124727400636987, max_depth=14, min_child_weight=34, n_estimators=118, reg_lambda=0.452459860467873
# [CV]  learning_rate=0.11124727400636987, max_depth=14, min_child_weight=34, n_estimators=118, reg_lambda=0.452459860467873, total=  14.0s
# [CV] learning_rate=0.11124727400636987, max_depth=14, min_child_weight=34, n_estimators=118, reg_lambda=0.452459860467873
# [CV]  learning_rate=0.11124727400636987, max_depth=14, min_child_weight=34, n_estimators=118, reg_lambda=0.452459860467873, total=  14.0s
# [CV] learning_rate=0.11124727400636987, max_depth=14, min_child_weight=34, n_estimators=118, reg_lambda=0.452459860467873
# [CV]  learning_rate=0.11124727400636987, max_depth=14, min_child_weight=34, n_estimators=118, reg_lambda=0.452459860467873, total=  14.0s
# [CV] learning_rate=0.11124727400636987, max_depth=14, min_child_weight=34, n_estimators=118, reg_lambda=0.452459860467873
# [CV]  learning_rate=0.11124727400636987, max_depth=14, min_child_weight=34, n_estimators=118, reg_lambda=0.452459860467873, total=  13.9s
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed: 65.1min finished
# 5.690265062135028 {'learning_rate': 0.09268431857373183, 'max_depth': 15, 'min_child_weight': 35, 'n_estimators': 125, 'reg_lambda': 2.396002296289432}

# %%
best_xgbregressor = joblib.load("data/best_xgbregressor.joblib")

# %%
print("Linear Regression:")
print(f"MSE: {mean_squared_error(y_val, model_linear_reg.predict(X_val_lda))}")
print(f"MAE: {mean_absolute_error(y_val, model_linear_reg.predict(X_val_lda))}")
print(f"R2: {r2_score(y_val, model_linear_reg.predict(X_val_lda))}\n")

print("XGBRegressor: ")
print(f"MSE: {mean_squared_error(y_val, best_xgbregressor.predict(X_val_lda))}")
print(f"MAE: {mean_absolute_error(y_val, best_xgbregressor.predict(X_val_lda))}")
print(f"R2: {r2_score(y_val, best_xgbregressor.predict(X_val_lda))}")
# Out:
# Linear Regression:
# MSE: 9.170182637761958
# MAE: 2.481524807848
# R2: 0.03655666894855314
#
# XGBRegressor:
# MSE: 5.690265062135028
# MAE: 1.9028470386356728
# R2: 0.4021658954257188

# %% [markdown]
# XGBRegressor scored better than Linear Regression. The results for XGBRegressor are rather satisfactory. Mean absolute error is 1,9 point whereas the scale comprises 20 points, so it's less than 10%. R2 maybe doesn't look amazing with 40% of variance in points explained by the model, but taking into account that rating of wine is quite subjective, the score is decent.

# %% [markdown]
# **Comparing classification and regression results**
#
#
# In order to compare classification and regression results, I calculate accuracy for regression in the following way: for each prediction from regression model I indicate the class to which it would belong based on the bins used for classification. In the same way I bin y_test. Thaks to this trick I can calculate the accuracy and compare it with the accuracy of the classification models.

# %%
# function to calculate accuracy for regression models

def calculate_regression_accuracy(bin_y, X, y, model):
  reg_acc = accuracy_score(bin_y(y), bin_y(model.predict(X).flatten()))
  return reg_acc

# %%
linear_reg_acc = calculate_regression_accuracy(bin_y, X_val_lda, y_val, model_linear_reg)
print(f"Accuracy of Linear Regression: {linear_reg_acc}")
# Out:
# Accuracy of Linear Regression: 0.6726381170317097

# %%
xgb_reg_acc = calculate_regression_accuracy(bin_y, X_val_lda, y_val, best_xgbregressor)
print(f"Accuracy of XGBRegressor: {xgb_reg_acc}")
# Out:
# Accuracy of XGBRegressor: 0.7289310232101994

# %% [markdown]
# ### LSTM

# %% [markdown]
# As in classification I will use pre-trained Glove Embeddings with 1.9 M vocabulary.

# %%
def build_lstm_model_3(list_of_layers):
  
  model = Sequential()
  model.add(Embedding(emb_matrix.shape[0],
                      emb_matrix.shape[1], 
                      input_length=max_len,
                      weights = [emb_matrix], 
                      trainable = False))
  for layer in list_of_layers:
    model.add(layer)
  model.summary() 
  
  model.compile(loss='mean_squared_error',
               optimizer="adam", 
               metrics=["mean_absolute_error"])
  return model

# %%
models =  {       
          "LSTM_300neurons":      [LSTM(300),
                                  Dense(1)],
    
          "LSTM_500neurons":      [LSTM(500),
                                  Dense(1)],
        
          "LSTM_1000neurons":      [LSTM(1000),
                                  Dense(1)],
          
          "BiLSTM_Dense":          [Bidirectional(LSTM(300)),
                                  Dense(1)],
          
          "MultipleLSTM_Dense":    [LSTM(200, return_sequences=True),
                                  LSTM(100),
                                  Dense(1)],
          
          "LSTM_MultipleDense":     [LSTM(300),
                                  Dense(30, activation="relu"),
                                  Dense(1)],
     
         
          "Conv_Pool_LSTM_Dense": [Conv1D(32,3),
                                   MaxPooling1D(pool_size=2),
                                   LSTM(100),
                                   Dense(1)]
}

# %%
lst = []
for model, params in models.items():
  mae = (evaluate_lstm_model(build_lstm_model_3(params), X_train_nn, X_val_nn, y_train, y_val, model))
  lst.append(mae)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 300)               721200
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 301
# =================================================================
# Total params: 10,478,701
# Trainable params: 721,501
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 158s 2ms/step - loss: 9.6301 - mean_squared_error: 9.6301 - mean_absolute_error: 2.5385 - val_loss: 9.6938 - val_mean_squared_error: 9.6938 - val_mean_absolute_error: 2.5563
# Epoch 2/100
# 69332/69332 [==============================] - 157s 2ms/step - loss: 9.6214 - mean_squared_error: 9.6214 - mean_absolute_error: 2.5385 - val_loss: 9.5567 - val_mean_squared_error: 9.5567 - val_mean_absolute_error: 2.5329
# Epoch 3/100
# 69332/69332 [==============================] - 156s 2ms/step - loss: 9.6157 - mean_squared_error: 9.6157 - mean_absolute_error: 2.5383 - val_loss: 9.5881 - val_mean_squared_error: 9.5881 - val_mean_absolute_error: 2.5452
# Epoch 4/100
# 69332/69332 [==============================] - 157s 2ms/step - loss: 9.6199 - mean_squared_error: 9.6199 - mean_absolute_error: 2.5375 - val_loss: 9.5616 - val_mean_squared_error: 9.5616 - val_mean_absolute_error: 2.5393
# Epoch 5/100
# 69332/69332 [==============================] - 157s 2ms/step - loss: 9.6252 - mean_squared_error: 9.6252 - mean_absolute_error: 2.5377 - val_loss: 9.6021 - val_mean_squared_error: 9.6021 - val_mean_absolute_error: 2.5224
# 15295/15295 [==============================] - 54s 4ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 500)               1602000
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 501
# =================================================================
# Total params: 11,359,701
# Trainable params: 1,602,501
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 201s 3ms/step - loss: 418.9246 - mean_squared_error: 418.9246 - mean_absolute_error: 11.6421 - val_loss: 9.5566 - val_mean_squared_error: 9.5566 - val_mean_absolute_error: 2.5367
# Epoch 2/100
# 69332/69332 [==============================] - 200s 3ms/step - loss: 9.5892 - mean_squared_error: 9.5892 - mean_absolute_error: 2.5375 - val_loss: 9.5647 - val_mean_squared_error: 9.5647 - val_mean_absolute_error: 2.5403
# Epoch 3/100
# 69332/69332 [==============================] - 200s 3ms/step - loss: 9.5903 - mean_squared_error: 9.5903 - mean_absolute_error: 2.5382 - val_loss: 9.5570 - val_mean_squared_error: 9.5570 - val_mean_absolute_error: 2.5370
# Epoch 4/100
# 69332/69332 [==============================] - 200s 3ms/step - loss: 9.5903 - mean_squared_error: 9.5903 - mean_absolute_error: 2.5377 - val_loss: 9.5598 - val_mean_squared_error: 9.5598 - val_mean_absolute_error: 2.5386
# 15295/15295 [==============================] - 55s 4ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 1000)              5204000
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 1001
# =================================================================
# Total params: 14,962,201
# Trainable params: 5,205,001
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 401s 6ms/step - loss: 161.4615 - mean_squared_error: 161.4615 - mean_absolute_error: 5.9378 - val_loss: 9.5716 - val_mean_squared_error: 9.5716 - val_mean_absolute_error: 2.5275
# Epoch 2/100
# 69332/69332 [==============================] - 399s 6ms/step - loss: 9.5947 - mean_squared_error: 9.5947 - mean_absolute_error: 2.5379 - val_loss: 9.5633 - val_mean_squared_error: 9.5633 - val_mean_absolute_error: 2.5399
# Epoch 3/100
# 69332/69332 [==============================] - 399s 6ms/step - loss: 9.5961 - mean_squared_error: 9.5961 - mean_absolute_error: 2.5382 - val_loss: 9.5856 - val_mean_squared_error: 9.5856 - val_mean_absolute_error: 2.5248
# Epoch 4/100
# 69332/69332 [==============================] - 399s 6ms/step - loss: 9.5974 - mean_squared_error: 9.5974 - mean_absolute_error: 2.5377 - val_loss: 9.5679 - val_mean_squared_error: 9.5679 - val_mean_absolute_error: 2.5284
# Epoch 5/100
# 69332/69332 [==============================] - 399s 6ms/step - loss: 9.6027 - mean_squared_error: 9.6027 - mean_absolute_error: 2.5374 - val_loss: 9.5569 - val_mean_squared_error: 9.5569 - val_mean_absolute_error: 2.5369
# Epoch 6/100
# 69332/69332 [==============================] - 398s 6ms/step - loss: 9.6183 - mean_squared_error: 9.6183 - mean_absolute_error: 2.5390 - val_loss: 9.5687 - val_mean_squared_error: 9.5687 - val_mean_absolute_error: 2.5279
# Epoch 7/100
# 69332/69332 [==============================] - 398s 6ms/step - loss: 9.6110 - mean_squared_error: 9.6110 - mean_absolute_error: 2.5377 - val_loss: 9.6600 - val_mean_squared_error: 9.6600 - val_mean_absolute_error: 2.5535
# Epoch 8/100
# 69332/69332 [==============================] - 398s 6ms/step - loss: 9.6134 - mean_squared_error: 9.6134 - mean_absolute_error: 2.5379 - val_loss: 9.6998 - val_mean_squared_error: 9.6998 - val_mean_absolute_error: 2.5567
# 15295/15295 [==============================] - 83s 5ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 600)               1442400
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 601
# =================================================================
# Total params: 11,200,201
# Trainable params: 1,443,001
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 325s 5ms/step - loss: 331.2053 - mean_squared_error: 331.2053 - mean_absolute_error: 9.2998 - val_loss: 9.5604 - val_mean_squared_error: 9.5604 - val_mean_absolute_error: 2.5388
# Epoch 2/100
# 69332/69332 [==============================] - 323s 5ms/step - loss: 9.5895 - mean_squared_error: 9.5895 - mean_absolute_error: 2.5378 - val_loss: 9.5578 - val_mean_squared_error: 9.5578 - val_mean_absolute_error: 2.5375
# Epoch 3/100
# 69332/69332 [==============================] - 324s 5ms/step - loss: 9.5910 - mean_squared_error: 9.5910 - mean_absolute_error: 2.5379 - val_loss: 9.5558 - val_mean_squared_error: 9.5558 - val_mean_absolute_error: 2.5340
# Epoch 4/100
# 69332/69332 [==============================] - 324s 5ms/step - loss: 9.5916 - mean_squared_error: 9.5916 - mean_absolute_error: 2.5377 - val_loss: 9.5607 - val_mean_squared_error: 9.5607 - val_mean_absolute_error: 2.5307
# Epoch 5/100
# 69332/69332 [==============================] - 324s 5ms/step - loss: 9.5928 - mean_squared_error: 9.5928 - mean_absolute_error: 2.5376 - val_loss: 9.5729 - val_mean_squared_error: 9.5729 - val_mean_absolute_error: 2.5424
# Epoch 6/100
# 69332/69332 [==============================] - 324s 5ms/step - loss: 9.5954 - mean_squared_error: 9.5954 - mean_absolute_error: 2.5375 - val_loss: 9.5556 - val_mean_squared_error: 9.5556 - val_mean_absolute_error: 2.5346
# Epoch 7/100
# 69332/69332 [==============================] - 325s 5ms/step - loss: 9.5981 - mean_squared_error: 9.5981 - mean_absolute_error: 2.5374 - val_loss: 9.5580 - val_mean_squared_error: 9.5580 - val_mean_absolute_error: 2.5376
# Epoch 8/100
# 69332/69332 [==============================] - 323s 5ms/step - loss: 9.6001 - mean_squared_error: 9.6001 - mean_absolute_error: 2.5372 - val_loss: 9.6552 - val_mean_squared_error: 9.6552 - val_mean_absolute_error: 2.5530
# Epoch 9/100
# 69332/69332 [==============================] - 324s 5ms/step - loss: 9.6128 - mean_squared_error: 9.6128 - mean_absolute_error: 2.5387 - val_loss: 9.5597 - val_mean_squared_error: 9.5597 - val_mean_absolute_error: 2.5385
# 15295/15295 [==============================] - 102s 7ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 136, 200)          400800
# _________________________________________________________________
# lstm_22 (LSTM)               (None, 100)               120400
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 10,278,501
# Trainable params: 521,301
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 309s 4ms/step - loss: 3072.9278 - mean_squared_error: 3072.9278 - mean_absolute_error: 53.7388 - val_loss: 1105.3211 - val_mean_squared_error: 1105.3211 - val_mean_absolute_error: 33.1023
# Epoch 2/100
# 69332/69332 [==============================] - 307s 4ms/step - loss: 445.8839 - mean_squared_error: 445.8839 - mean_absolute_error: 19.7362 - val_loss: 99.8952 - val_mean_squared_error: 99.8952 - val_mean_absolute_error: 9.5047
# Epoch 3/100
# 69332/69332 [==============================] - 308s 4ms/step - loss: 36.1917 - mean_squared_error: 36.1917 - mean_absolute_error: 4.9904 - val_loss: 11.8153 - val_mean_squared_error: 11.8153 - val_mean_absolute_error: 2.7408
# Epoch 4/100
# 69332/69332 [==============================] - 307s 4ms/step - loss: 10.0827 - mean_squared_error: 10.0827 - mean_absolute_error: 2.5679 - val_loss: 9.5651 - val_mean_squared_error: 9.5651 - val_mean_absolute_error: 2.5292
# Epoch 5/100
# 69332/69332 [==============================] - 308s 4ms/step - loss: 9.5904 - mean_squared_error: 9.5904 - mean_absolute_error: 2.5358 - val_loss: 9.5558 - val_mean_squared_error: 9.5558 - val_mean_absolute_error: 2.5357
# Epoch 6/100
# 69332/69332 [==============================] - 308s 4ms/step - loss: 9.5884 - mean_squared_error: 9.5884 - mean_absolute_error: 2.5378 - val_loss: 9.5559 - val_mean_squared_error: 9.5559 - val_mean_absolute_error: 2.5359
# Epoch 7/100
# 69332/69332 [==============================] - 308s 4ms/step - loss: 9.5886 - mean_squared_error: 9.5886 - mean_absolute_error: 2.5379 - val_loss: 9.5561 - val_mean_squared_error: 9.5561 - val_mean_absolute_error: 2.5361
# Epoch 8/100
# 69332/69332 [==============================] - 307s 4ms/step - loss: 9.5880 - mean_squared_error: 9.5880 - mean_absolute_error: 2.5376 - val_loss: 9.5571 - val_mean_squared_error: 9.5571 - val_mean_absolute_error: 2.5370
# 15295/15295 [==============================] - 104s 7ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 300)               721200
# _________________________________________________________________
# dense_22 (Dense)             (None, 30)                9030
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 10,487,461
# Trainable params: 730,261
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 161s 2ms/step - loss: 293.5038 - mean_squared_error: 293.5038 - mean_absolute_error: 7.2330 - val_loss: 9.5758 - val_mean_squared_error: 9.5758 - val_mean_absolute_error: 2.5430
# Epoch 2/100
# 69332/69332 [==============================] - 157s 2ms/step - loss: 9.5957 - mean_squared_error: 9.5957 - mean_absolute_error: 2.5380 - val_loss: 9.5563 - val_mean_squared_error: 9.5563 - val_mean_absolute_error: 2.5333
# Epoch 3/100
# 69332/69332 [==============================] - 159s 2ms/step - loss: 9.6041 - mean_squared_error: 9.6041 - mean_absolute_error: 2.5379 - val_loss: 9.5742 - val_mean_squared_error: 9.5742 - val_mean_absolute_error: 2.5269
# Epoch 4/100
# 69332/69332 [==============================] - 157s 2ms/step - loss: 9.6053 - mean_squared_error: 9.6053 - mean_absolute_error: 2.5376 - val_loss: 9.5690 - val_mean_squared_error: 9.5690 - val_mean_absolute_error: 2.5415
# Epoch 5/100
# 69332/69332 [==============================] - 158s 2ms/step - loss: 9.6155 - mean_squared_error: 9.6155 - mean_absolute_error: 2.5382 - val_loss: 9.5557 - val_mean_squared_error: 9.5557 - val_mean_absolute_error: 2.5341
# Epoch 6/100
# 69332/69332 [==============================] - 158s 2ms/step - loss: 9.6205 - mean_squared_error: 9.6205 - mean_absolute_error: 2.5380 - val_loss: 9.5584 - val_mean_squared_error: 9.5584 - val_mean_absolute_error: 2.5379
# Epoch 7/100
# 69332/69332 [==============================] - 159s 2ms/step - loss: 9.6317 - mean_squared_error: 9.6317 - mean_absolute_error: 2.5376 - val_loss: 9.6054 - val_mean_squared_error: 9.6054 - val_mean_absolute_error: 2.5477
# Epoch 8/100
# 69332/69332 [==============================] - 158s 2ms/step - loss: 9.6601 - mean_squared_error: 9.6601 - mean_absolute_error: 2.5399 - val_loss: 9.5907 - val_mean_squared_error: 9.5907 - val_mean_absolute_error: 2.5456
# 15295/15295 [==============================] - 55s 4ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_10 (Embedding)     (None, 136, 300)          9757200
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 134, 32)           28832
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 67, 32)            0
# _________________________________________________________________
# lstm_24 (LSTM)               (None, 100)               53200
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 9,839,333
# Trainable params: 82,133
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Train on 69332 samples, validate on 17334 samples
# Epoch 1/100
# 69332/69332 [==============================] - 95s 1ms/step - loss: 3041.1726 - mean_squared_error: 3041.1726 - mean_absolute_error: 53.3063 - val_loss: 1042.0028 - val_mean_squared_error: 1042.0028 - val_mean_absolute_error: 32.1317
# Epoch 2/100
# 69332/69332 [==============================] - 90s 1ms/step - loss: 409.0754 - mean_squared_error: 409.0754 - mean_absolute_error: 18.8011 - val_loss: 86.0368 - val_mean_squared_error: 86.0368 - val_mean_absolute_error: 8.7454
# Epoch 3/100
# 69332/69332 [==============================] - 91s 1ms/step - loss: 31.2502 - mean_squared_error: 31.2502 - mean_absolute_error: 4.5972 - val_loss: 11.1254 - val_mean_squared_error: 11.1254 - val_mean_absolute_error: 2.6733
# Epoch 4/100
# 69332/69332 [==============================] - 91s 1ms/step - loss: 9.9130 - mean_squared_error: 9.9130 - mean_absolute_error: 2.5510 - val_loss: 9.5587 - val_mean_squared_error: 9.5587 - val_mean_absolute_error: 2.5316
# Epoch 5/100
# 69332/69332 [==============================] - 90s 1ms/step - loss: 9.5883 - mean_squared_error: 9.5883 - mean_absolute_error: 2.5363 - val_loss: 9.5578 - val_mean_squared_error: 9.5578 - val_mean_absolute_error: 2.5375
# Epoch 6/100
# 69332/69332 [==============================] - 90s 1ms/step - loss: 9.5884 - mean_squared_error: 9.5884 - mean_absolute_error: 2.5381 - val_loss: 9.5560 - val_mean_squared_error: 9.5560 - val_mean_absolute_error: 2.5360
# Epoch 7/100
# 69332/69332 [==============================] - 90s 1ms/step - loss: 9.5884 - mean_squared_error: 9.5884 - mean_absolute_error: 2.5378 - val_loss: 9.5558 - val_mean_squared_error: 9.5558 - val_mean_absolute_error: 2.5357
# Epoch 8/100
# 69332/69332 [==============================] - 90s 1ms/step - loss: 9.5885 - mean_squared_error: 9.5885 - mean_absolute_error: 2.5380 - val_loss: 9.5556 - val_mean_squared_error: 9.5556 - val_mean_absolute_error: 2.5346
# Epoch 9/100
# 69332/69332 [==============================] - 90s 1ms/step - loss: 9.5890 - mean_squared_error: 9.5890 - mean_absolute_error: 2.5378 - val_loss: 9.5560 - val_mean_squared_error: 9.5560 - val_mean_absolute_error: 2.5360
# Epoch 10/100
# 69332/69332 [==============================] - 91s 1ms/step - loss: 9.5895 - mean_squared_error: 9.5895 - mean_absolute_error: 2.5379 - val_loss: 9.5576 - val_mean_squared_error: 9.5576 - val_mean_absolute_error: 2.5374
# Epoch 11/100
# 69332/69332 [==============================] - 90s 1ms/step - loss: 9.5892 - mean_squared_error: 9.5892 - mean_absolute_error: 2.5379 - val_loss: 9.5577 - val_mean_squared_error: 9.5577 - val_mean_absolute_error: 2.5374
# 15295/15295 [==============================] - 27s 2ms/step

# %%
lstm_3_results = pd.DataFrame(list(zip(models.keys(), lst)), columns=["model", "MSE"]).sort_values(by="MSE", ascending=True).reset_index(drop=True)

# %%
lstm_3_results
# Out:
#                   model       MSE
# 0       LSTM_300neurons  9.518730
# 1    LSTM_MultipleDense  9.520288
# 2  Conv_Pool_LSTM_Dense  9.521109
# 3          BiLSTM_Dense  9.521109
# 4    MultipleLSTM_Dense  9.523565
# 5       LSTM_500neurons  9.526321
# 6      LSTM_1000neurons  9.526927

# %%
# loading best NN regression model and calculating accuracy

best_nn_reg = build_lstm_model_3(models["LSTM_300neurons"])
best_nn_reg.load_weights("data/LSTM_300neurons.h5py")
best_nn_reg.compile(loss='mean_squared_error',
               optimizer="adam", 
               metrics=["mean_absolute_error"])
nn_reg_acc = calculate_regression_accuracy(bin_y, X_val_nn, y_val, best_nn_reg)
print(f"Accuracy of best NN for regression: {nn_reg_acc}")
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_14 (Embedding)     (None, 136, 300)          9757200
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 300)               721200
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 301
# =================================================================
# Total params: 10,478,701
# Trainable params: 721,501
# Non-trainable params: 9,757,200
# _________________________________________________________________
# Accuracy of best NN for regression: 0.6726381170317097

# %% [markdown]
# All of the LSTM models has very similar MSE value. The best model (lowest MSE) is the simplest: LSTM network with 300 neurons. However, MSE is higher than for both Linear Regression (minimal difference) and for XBGRegressor, which is clear winner with MSE 5,7. It has also the highest accuracy: 0.73.

# %% [markdown]
# ### Score on test set

# %% [markdown]
# The best model of all models tested for regression is XGBRegressor. Let's check how it scores on test set.

# %%
# loading best model from a file and evaluating on test set

best_reg_acc = calculate_regression_accuracy(bin_y, X_test_lda, y_test, best_xgbregressor)
print(f"Accuracy of best model for regression: {best_reg_acc}")
# Out:
# Accuracy of best model for regression: 0.7300211181504946

# %% [markdown]
# # Summary

# %% [markdown]
# Predicting wine rating on the basis of its description can be treated in three ways: as Nominal Classification, Ordinal Classification and Regression. It turned out that LSTM for Nominal Classification and NNRank for Ordinal Classification scored almost the same (nominal slightly better) leaving Regression behind. It's an interesting result as I supposed that taking into accound ordinality of classes would improve the accuracy. However, it seems that in this particular problem the effect of ordinality wasn't that big.
#
# Table below shows best model for every approach and its accuracy on test set.
#
# There were two things that surprised me during this project. First, that the terms used by professional sommeliers and wine-tasters to describe wines are not as random as they appeared to me before and they are actually good predictors for wine quality (supposing rating reflects wine quality). Second is the fact that there are so few Python implementations for Ordinal Classification. It seems like a field for further research.

# %%
pd.DataFrame(data = {"approach": ["Nominal Classification", "Ordinal Classification", "Regression"],
              "models": ["LSTM(300)+Dense(30)+Dense(3)", "LSTM(200)+LSTM(100)+Dense(3) ", "XGBREgressor"],
               "accuracy": [best_nom_acc, best_ord_acc, best_reg_acc]})
# Out:
#    accuracy                approach                         models
# 0  0.820162  Nominal Classification   LSTM(300)+Dense(30)+Dense(3)
# 1  0.817995  Ordinal Classification  LSTM(200)+LSTM(100)+Dense(3)
# 2  0.730021              Regression                   XGBREgressor
